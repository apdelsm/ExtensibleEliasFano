# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
confIds = pd.read_csv('./configurationIds.csv', delimiter=';')

tuplesLineal = pd.read_csv('./tupleLineal.csv', delimiter=';')
tuplesInterpolation = pd.read_csv('./tupleInterpolation.csv', delimiter=';')
tuplesBinary = pd.read_csv('./tupleBinary.csv', delimiter=';')
btree = pd.read_csv('./btreeMap.csv', delimiter=';')
redBlack = pd.read_csv('./redBlackTree.csv', delimiter=';')
avl = pd.read_csv('./avlMap.csv', delimiter=';')
xfast = pd.read_csv('./xFastMap.csv', delimiter=';')
yfastUR = pd.read_csv('./yFastMapUR.csv', delimiter=';')
yfast = pd.read_csv('./yFastMapNUR.csv', delimiter=';')
sd_vectorRB = pd.read_csv('./sdVectorRandomBits.csv', delimiter=';')

# %%
bufferSizes = [1024, 2048, 4096]
x = np.arange(len(bufferSizes))

# %% [markdown]
# # Random Bits

# %% [markdown]
# ## Random Bits Sizes

# %%
tuplesLineal0Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
btree0Size = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
redBlack0Size = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
avl0Size = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
xfast0Size = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
yfastUR0Size = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
yfast0Size = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Size']*8/100000000,
]

tuplesLineal1Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
btree1Size = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
redBlack1Size = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
avl1Size = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
xfast1Size = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
yfastUR1Size = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
yfast1Size = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Size']*8/100000000,
]

tuplesLineal2Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
btree2Size = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
redBlack2Size = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
avl2Size = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
xfast2Size = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
yfastUR2Size = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
yfast2Size = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
tuplesLineal3Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
btree3Size = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
redBlack3Size = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
avl3Size = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
xfast3Size = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
yfastUR3Size = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
yfast3Size = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Size']*8/100000000,
]

sd_vectorRB0Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB1Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB2Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB3Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Size']*8/100000000]*3

width = 0.1
fig, ax = plt.subplots(2, 2, figsize=(15, 12), sharey=False)
fig.supxlabel('Tamaño del buffer')
fig.supylabel('Bits usados por bit recibido')
fig.suptitle('Cantidad de bits utilizados por bit recibido para los distintos tamaños de buffer')
ax[0,0].bar(x - 0.35, tuplesLineal0Size, width, label = 'tuples')
ax[0,0].bar(x - 0.25, btree0Size, width, label = 'btree')
ax[0,0].bar(x - 0.15, redBlack0Size, width, label = 'redBlack')
ax[0,0].bar(x - 0.05, yfastUR0Size, width, label = 'yfastUR')
ax[0,0].bar(x + 0.05, yfast0Size, width, label = 'yfast')
ax[0,0].bar(x + 0.15, xfast0Size, width, label = 'xfast')
ax[0,0].bar(x + 0.25, avl0Size, width, label = 'avl')
ax[0,0].bar(x + 0.35, sd_vectorRB0Size, width, label = 'sd vector')
ax[0,0].set_title('Densidad 0.01')
ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(bufferSizes)
ax[0,1].bar(x - 0.35, tuplesLineal1Size, width, label = 'tuples')
ax[0,1].bar(x - 0.25, btree1Size, width, label = 'btree')
ax[0,1].bar(x - 0.15, redBlack1Size, width, label = 'redBlack')
ax[0,1].bar(x - 0.05, yfastUR1Size, width, label = 'yfastUR')
ax[0,1].bar(x + 0.05, yfast1Size, width, label = 'yfast')
ax[0,1].bar(x + 0.15, xfast1Size, width, label = 'xfast')
ax[0,1].bar(x + 0.25, avl1Size, width, label = 'avl')
ax[0,1].bar(x + 0.35, sd_vectorRB1Size, width, label = 'sd vector')
ax[0,1].set_title('Densidad 0.05')
ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(bufferSizes)
ax[1,0].bar(x - 0.35, tuplesLineal2Size, width, label = 'tuples')
ax[1,0].bar(x - 0.25, btree2Size, width, label = 'btree')
ax[1,0].bar(x - 0.15, redBlack2Size, width, label = 'redBlack')
ax[1,0].bar(x - 0.05, yfastUR2Size, width, label = 'yfastUR')
ax[1,0].bar(x + 0.05, yfast2Size, width, label = 'yfast')
ax[1,0].bar(x + 0.15, xfast2Size, width, label = 'xfast')
ax[1,0].bar(x + 0.25, avl2Size, width, label = 'avl')
ax[1,0].bar(x + 0.35, sd_vectorRB2Size, width, label = 'sd vector')
ax[1,0].set_title('Densidad 0.1')
ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(bufferSizes)
ax[1,1].bar(x - 0.35, tuplesLineal3Size, width, label = 'tuples')
ax[1,1].bar(x - 0.25, btree3Size, width, label = 'btree')
ax[1,1].bar(x - 0.15, redBlack3Size, width, label = 'redBlack')
ax[1,1].bar(x - 0.05, yfastUR3Size, width, label = 'yfastUR')
ax[1,1].bar(x + 0.05, yfast3Size, width, label = 'yfast')
ax[1,1].bar(x + 0.15, xfast3Size, width, label = 'xfast')
ax[1,1].bar(x + 0.25, avl3Size, width, label = 'avl')
ax[1,1].bar(x + 0.35, sd_vectorRB3Size, width, label = 'sd vector')
ax[1,1].set_title('Densidad 0.12')
ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(bufferSizes)
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')
plt.show()

# %% [markdown]
# ## Random Bits Insert Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ones']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ones']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ones']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 93].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 184].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ones']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ones']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 93].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 184].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ones']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ones']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ones']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ones']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ones']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ones']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ones']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 99].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 190].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ones']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ones']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 99].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 190].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ones']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ones']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ones']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ones']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ones']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ones']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ones']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 92].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 183].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ones']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ones']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 92].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 183].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ones']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ones']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ones']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ones']*100,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ones']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ones']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ones']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 95].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 186].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ones']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ones']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 95].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 186].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ones']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ones']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ones']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*100,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*100]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*100]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*100]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*100]*3

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
#ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd_vector')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Densidad 0.01')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
#ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Densidad 0.05')
ax[1,0].plot(bufferSizes, tuplesMean2Time, label = 'Tuples')
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl')
#ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Densidad 0.1')
ax[1,1].plot(bufferSizes, tuplesMean3Time, label = 'Tuples')
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl')
#ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Densidad 0.12')
fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()
print(sd_vectorRB0Time)
print(sd_vectorRB1Time)
print(sd_vectorRB2Time)
print(sd_vectorRB3Time)
# Out:
# [5.041410844764561e-05, 5.041410844764561e-05, 5.041410844764561e-05]
# [0.00047560824132081216, 0.00047560824132081216, 0.00047560824132081216]
# [0.001011950165268243, 0.001011950165268243, 0.001011950165268243]
# [0.001015976624859845, 0.001015976624859845, 0.001015976624859845]

# %% [markdown]
# ## Random Bits Rank Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ranks']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ranks']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ranks']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ranks']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ranks']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ranks']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ranks']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ranks']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ranks']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ranks']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ranks']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ranks']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ranks']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ranks']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ranks']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ranks']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ranks']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ranks']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ranks']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ranks']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ranks']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ranks']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ranks']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ranks']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*100,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ranks']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ranks']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ranks']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ranks']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ranks']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ranks']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ranks']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ranks']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*100,
]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*100]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*100]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*100]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*100]*3

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples Lineal')
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples Binary')
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples Interpolation')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd_vector')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Densidad 0.01')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary')
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Densidad 0.05')
ax[1,0].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal')
ax[1,0].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary')
ax[1,0].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation')
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl')
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Densidad 0.1')
ax[1,1].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal')
ax[1,1].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary')
ax[1,1].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation')
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Densidad 0.12')
fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples Binary')
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples Interpolation')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd_vector')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Densidad 0.01')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary')
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Densidad 0.05')
ax[1,0].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary')
ax[1,0].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation')
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl')
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Densidad 0.1')
ax[1,1].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary')
ax[1,1].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation')
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Densidad 0.12')
fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

# %% [markdown]
# ## Random Bits Select Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Selects']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Selects']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Selects']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Selects']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Selects']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Selects']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Selects']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Selects']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Selects']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Selects']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Selects']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Selects']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Selects']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Selects']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Selects']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Selects']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Selects']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Selects']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Selects']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Selects']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Selects']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Selects']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Selects']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Selects']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Selects']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Selects']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Selects']*100,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Selects']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Selects']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Selects']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Selects']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Selects']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Selects']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Selects']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Selects']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Selects']*100,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*100]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*100]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*100]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*100]*3

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd_vector')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Densidad 0.01')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Densidad 0.05')
ax[1,0].plot(bufferSizes, tuplesMean2Time, label = 'Tuples')
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl')
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Densidad 0.1')
ax[1,1].plot(bufferSizes, tuplesMean3Time, label = 'Tuples')
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Densidad 0.12')
fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Densidad 0.01')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Densidad 0.05')
ax[1,0].plot(bufferSizes, tuplesMean2Time, label = 'Tuples')
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Densidad 0.1')
ax[1,1].plot(bufferSizes, tuplesMean3Time, label = 'Tuples')
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Densidad 0.12')
fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

# %% [markdown]
# # Random Runs

# %% [markdown]
# ## Random Runs Size

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
btree0Size = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
redBlack0Size = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
avl0Size = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
xfast0Size = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
yfastUR0Size = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
yfast0Size = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Size']*8/100000000,
]

tuplesLineal1Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
btree1Size = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
redBlack1Size = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
avl1Size = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
xfast1Size = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
yfastUR1Size = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
yfast1Size = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Size']*8/100000000,
]

tuplesLineal2Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
btree2Size = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
redBlack2Size = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
avl2Size = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
xfast2Size = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
yfastUR2Size = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
yfast2Size = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Size']*8/100000000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
btree3Size = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
redBlack3Size = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
avl3Size = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
xfast3Size = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
yfastUR3Size = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
yfast3Size = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Size']*8/100000000,
]

tuplesLineal4Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
btree4Size = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
redBlack4Size = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
avl4Size = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
xfast4Size = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
yfastUR4Size = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
yfast4Size = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Size']*8/100000000,
]

tuplesLineal5Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
btree5Size = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
redBlack5Size = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
avl5Size = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
xfast5Size = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
yfastUR5Size = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
yfast5Size = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Size']*8/100000000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
btree6Size = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
redBlack6Size = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
avl6Size = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
xfast6Size = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
yfastUR6Size = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
yfast6Size = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Size']*8/100000000,
]

tuplesLineal7Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
btree7Size = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
redBlack7Size = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
avl7Size = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
xfast7Size = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
yfastUR7Size = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
yfast7Size = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Size']*8/100000000,
]

tuplesLineal8Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
btree8Size = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
redBlack8Size = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
avl8Size = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
xfast8Size = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
yfastUR8Size = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
yfast8Size = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Size']*8/100000000,
]

width = 0.1
fig, ax = plt.subplots(3, 3, figsize=(15, 12))
fig.supxlabel('Tamaño del buffer')
fig.supylabel('Bits usados por bit recibido')
fig.suptitle('Cantidad de bits utilizados por bit recibido para los distintos tamaños de buffer para una probabilidad de run de 0.01')
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].bar(x - 0.35, tuplesLineal0Size, width, label = 'tuples')
ax[0,0].bar(x - 0.25, btree0Size, width, label = 'btree')
ax[0,0].bar(x - 0.15, redBlack0Size, width, label = 'redBlack')
ax[0,0].bar(x - 0.05, yfastUR0Size, width, label = 'yfastUR')
ax[0,0].bar(x + 0.05, yfast0Size, width, label = 'yfast')
ax[0,0].bar(x + 0.15, xfast0Size, width, label = 'xfast')
ax[0,0].bar(x + 0.25, avl0Size, width, label = 'avl')
ax[0,0].set_title('Max run 2048, prob. 0.01, densidad ' + str(density0))
ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(bufferSizes)
ax[0,1].bar(x - 0.35, tuplesLineal1Size, width, label = 'tuples')
ax[0,1].bar(x - 0.25, btree1Size, width, label = 'btree')
ax[0,1].bar(x - 0.15, redBlack1Size, width, label = 'redBlack')
ax[0,1].bar(x - 0.05, yfastUR1Size, width, label = 'yfastUR')
ax[0,1].bar(x + 0.05, yfast1Size, width, label = 'yfast')
ax[0,1].bar(x + 0.15, xfast1Size, width, label = 'xfast')
ax[0,1].bar(x + 0.25, avl1Size, width, label = 'avl')
ax[0,1].set_title('Max run 4096, prob. 0.01, densidad ' + str(density1))
ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(bufferSizes)
ax[0,2].bar(x - 0.35, tuplesLineal2Size, width, label = 'tuples')
ax[0,2].bar(x - 0.25, btree2Size, width, label = 'btree')
ax[0,2].bar(x - 0.15, redBlack2Size, width, label = 'redBlack')
ax[0,2].bar(x - 0.05, yfastUR2Size, width, label = 'yfastUR')
ax[0,2].bar(x + 0.05, yfast2Size, width, label = 'yfast')
ax[0,2].bar(x + 0.15, xfast2Size, width, label = 'xfast')
ax[0,2].bar(x + 0.25, avl2Size, width, label = 'avl')
ax[0,2].set_title('Max run 8192, prob. 0.01, densidad ' + str(density2))
ax[0,2].set_xticks(x)
ax[0,2].set_xticklabels(bufferSizes)
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].bar(x - 0.35, tuplesLineal3Size, width, label = 'tuples')
ax[1,0].bar(x - 0.25, btree3Size, width, label = 'btree')
ax[1,0].bar(x - 0.15, redBlack3Size, width, label = 'redBlack')
ax[1,0].bar(x - 0.05, yfastUR3Size, width, label = 'yfastUR')
ax[1,0].bar(x + 0.05, yfast3Size, width, label = 'yfast')
ax[1,0].bar(x + 0.15, xfast3Size, width, label = 'xfast')
ax[1,0].bar(x + 0.25, avl3Size, width, label = 'avl')
ax[1,0].set_title('Max run 2048, prob. 0.05, densidad ' + str(density3))
ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(bufferSizes)
ax[1,1].bar(x - 0.35, tuplesLineal4Size, width, label = 'tuples')
ax[1,1].bar(x - 0.25, btree4Size, width, label = 'btree')
ax[1,1].bar(x - 0.15, redBlack4Size, width, label = 'redBlack')
ax[1,1].bar(x - 0.05, yfastUR4Size, width, label = 'yfastUR')
ax[1,1].bar(x + 0.05, yfast4Size, width, label = 'yfast')
ax[1,1].bar(x + 0.15, xfast4Size, width, label = 'xfast')
ax[1,1].bar(x + 0.25, avl4Size, width, label = 'avl')
ax[1,1].set_title('Max run 4096, prob. 0.05, densidad ' + str(density4))
ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(bufferSizes)
ax[1,2].bar(x - 0.35, tuplesLineal5Size, width, label = 'tuples')
ax[1,2].bar(x - 0.25, btree5Size, width, label = 'btree')
ax[1,2].bar(x - 0.15, redBlack5Size, width, label = 'redBlack')
ax[1,2].bar(x - 0.05, yfastUR5Size, width, label = 'yfastUR')
ax[1,2].bar(x + 0.05, yfast5Size, width, label = 'yfast')
ax[1,2].bar(x + 0.15, xfast5Size, width, label = 'xfast')
ax[1,2].bar(x + 0.25, avl5Size, width, label = 'avl')
ax[1,2].set_title('Max run 8192, prob. 0.05, densidad ' + str(density5))
ax[1,2].set_xticks(x)
ax[1,2].set_xticklabels(bufferSizes)
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].bar(x - 0.35, tuplesLineal6Size, width, label = 'tuples')
ax[2,0].bar(x - 0.25, btree6Size, width, label = 'btree')
ax[2,0].bar(x - 0.15, redBlack6Size, width, label = 'redBlack')
ax[2,0].bar(x - 0.05, yfastUR6Size, width, label = 'yfastUR')
ax[2,0].bar(x + 0.05, yfast6Size, width, label = 'yfast')
ax[2,0].bar(x + 0.15, xfast6Size, width, label = 'xfast')
ax[2,0].bar(x + 0.25, avl6Size, width, label = 'avl')
ax[2,0].set_title('Max run 2048, prob. 0.1, densidad ' + str(density6))
ax[2,0].set_xticks(x)
ax[2,0].set_xticklabels(bufferSizes)
ax[2,1].bar(x - 0.35, tuplesLineal7Size, width, label = 'tuples')
ax[2,1].bar(x - 0.25, btree7Size, width, label = 'btree')
ax[2,1].bar(x - 0.15, redBlack7Size, width, label = 'redBlack')
ax[2,1].bar(x - 0.05, yfastUR7Size, width, label = 'yfastUR')
ax[2,1].bar(x + 0.05, yfast7Size, width, label = 'yfast')
ax[2,1].bar(x + 0.15, xfast7Size, width, label = 'xfast')
ax[2,1].bar(x + 0.25, avl7Size, width, label = 'avl')
ax[2,1].set_title('Max run 4096, prob. 0.1, densidad ' + str(density7))
ax[2,1].set_xticks(x)
ax[2,1].set_xticklabels(bufferSizes)
ax[2,2].bar(x - 0.35, tuplesLineal8Size, width, label = 'tuples')
ax[2,2].bar(x - 0.25, btree8Size, width, label = 'btree')
ax[2,2].bar(x - 0.15, redBlack8Size, width, label = 'redBlack')
ax[2,2].bar(x - 0.05, yfastUR8Size, width, label = 'yfastUR')
ax[2,2].bar(x + 0.05, yfast8Size, width, label = 'yfast')
ax[2,2].bar(x + 0.15, xfast8Size, width, label = 'xfast')
ax[2,2].bar(x + 0.25, avl8Size, width, label = 'avl')
ax[2,2].set_title('Max run 8192, prob. 0.1, densidad ' + str(density8))
ax[2,2].set_xticks(x)
ax[2,2].set_xticklabels(bufferSizes)

handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')
plt.show()

# %% [markdown]
# ## Random Runs Insert Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ones']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ones']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ones']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 106].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 197].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ones']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ones']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 106].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 197].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ones']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ones']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ones']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ones']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ones']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ones']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ones']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 119].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 210].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ones']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ones']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 119].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 210].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ones']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ones']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ones']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ones']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ones']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ones']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ones']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 132].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 223].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ones']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ones']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 132].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 223].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ones']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ones']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ones']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ones']*100,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ones']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ones']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ones']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 112].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 203].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ones']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ones']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 112].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 203].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ones']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ones']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ones']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ones']*100,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ones']*100,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ones']*100,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ones']*100,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 125].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 216].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ones']*100,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ones']*100,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 125].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 216].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ones']*100,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ones']*100,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ones']*100,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ones']*100,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ones']*100,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ones']*100,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ones']*100,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 138].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 229].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ones']*100,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ones']*100,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 138].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 229].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ones']*100,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ones']*100,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ones']*100,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ones']*100,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ones']*100,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ones']*100,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ones']*100,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 105].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 196].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ones']*100,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ones']*100,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 105].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 196].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ones']*100,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ones']*100,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ones']*100,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ones']*100,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ones']*100,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ones']*100,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ones']*100,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 118].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 209].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ones']*100,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ones']*100,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 118].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 209].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ones']*100,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ones']*100,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ones']*100,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ones']*100,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ones']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ones']*100,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ones']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ones']*100,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ones']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ones']*100,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 131].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ones']*100,
  btree.loc[btree['confID'] == 222].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ones']*100,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ones']*100,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ones']*100,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 131].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ones']*100,
  avl.loc[avl['confID'] == 222].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ones']*100,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ones']*100,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ones']*100,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ones']*100,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ones']*100,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ones']*100,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ones']*100,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]


fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
#ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Max run 2048, prob. 0.01, densidad ' + str(density0))
#ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Max run 4096, prob. 0.01, densidad ' + str(density1))
#ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Tuples')
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree')
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].set_title('Max run 8192, prob. 0.01, densidad ' + str(density2))
#ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Tuples')
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Max run 2048, prob. 0.05, densidad ' + str(density3))
#ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Tuples')
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Max run 4096, prob. 0.05, densidad ' + str(density4))
#ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Tuples')
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree')
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack')
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR')
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast')
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast')
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].set_title('Max run 8192, prob. 0.05, densidad ' + str(density5))
#ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Tuples')
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree')
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack')
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR')
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast')
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast')
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].set_title('Max run 2048, prob. 0.1, densidad ' + str(density6))
#ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Tuples')
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree')
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack')
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR')
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast')
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast')
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].set_title('Max run 4096, prob. 0.1, densidad ' + str(density7))
#ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Tuples')
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree')
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack')
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR')
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast')
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast')
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].set_title('Max run 8192, prob. 0.1, densidad ' + str(density8))

fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()
#print(sd_vectorRB0Time)
#print(sd_vectorRB1Time)
#print(sd_vectorRB2Time)
#print(sd_vectorRB3Time)

# %% [markdown]
# ## Random Runs Rank Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ranks']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ranks']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ranks']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ranks']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ranks']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ranks']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ranks']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ranks']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ranks']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ranks']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ranks']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ranks']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ranks']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ranks']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ranks']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ranks']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ranks']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ranks']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ranks']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ranks']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ranks']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ranks']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ranks']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ranks']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*100,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ranks']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ranks']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ranks']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ranks']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ranks']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ranks']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ranks']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ranks']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*100,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ranks']*100,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ranks']*100,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ranks']*100,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ranks']*100,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ranks']*100,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ranks']*100,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ranks']*100,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ranks']*100,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*100,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ranks']*100,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ranks']*100,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ranks']*100,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ranks']*100,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ranks']*100,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ranks']*100,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ranks']*100,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ranks']*100,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*100,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ranks']*100,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ranks']*100,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ranks']*100,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ranks']*100,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ranks']*100,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ranks']*100,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ranks']*100,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ranks']*100,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*100,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ranks']*100,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ranks']*100,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ranks']*100,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ranks']*100,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ranks']*100,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ranks']*100,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ranks']*100,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ranks']*100,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*100,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ranks']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ranks']*100,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ranks']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ranks']*100,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ranks']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ranks']*100,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ranks']*100,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ranks']*100,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ranks']*100,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ranks']*100,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ranks']*100,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ranks']*100,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ranks']*100,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ranks']*100,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ranks']*100,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ranks']*100,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ranks']*100,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*100,
]

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples Lineal')
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples Interpolation')
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples Binary')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Max run 2048, prob. 0.01, densidad ' + str(density0))
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal')
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Max run 4096, prob. 0.01, densidad ' + str(density1))
ax[0,2].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal')
ax[0,2].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation')
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary')
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree')
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].set_title('Max run 8192, prob. 0.01, densidad ' + str(density2))
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal')
ax[1,0].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation')
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary')
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Max run 2048, prob. 0.05, densidad ' + str(density3))
ax[1,1].plot(bufferSizes, tuplesLineal4Time, label = 'Tuples Lineal')
ax[1,1].plot(bufferSizes, tuplesInterpolation4Time, label = 'Tuples Interpolation')
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary')
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Max run 4096, prob. 0.05, densidad ' + str(density4))
ax[1,2].plot(bufferSizes, tuplesLineal5Time, label = 'Tuples Lineal')
ax[1,2].plot(bufferSizes, tuplesInterpolation5Time, label = 'Tuples Interpolation')
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary')
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree')
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack')
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR')
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast')
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast')
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].set_title('Max run 8192, prob. 0.05, densidad ' + str(density5))
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesLineal6Time, label = 'Tuples Lineal')
ax[2,0].plot(bufferSizes, tuplesInterpolation6Time, label = 'Tuples Interpolation')
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary')
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree')
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack')
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR')
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast')
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast')
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].set_title('Max run 2048, prob. 0.1, densidad ' + str(density6))
ax[2,1].plot(bufferSizes, tuplesLineal7Time, label = 'Tuples Lineal')
ax[2,1].plot(bufferSizes, tuplesInterpolation7Time, label = 'Tuples Interpolation')
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary')
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree')
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack')
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR')
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast')
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast')
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].set_title('Max run 4096, prob. 0.1, densidad ' + str(density7))
ax[2,2].plot(bufferSizes, tuplesLineal8Time, label = 'Tuples Lineal')
ax[2,2].plot(bufferSizes, tuplesInterpolation8Time, label = 'Tuples Interpolation')
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary')
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree')
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack')
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR')
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast')
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast')
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].set_title('Max run 8192, prob. 0.1, densidad ' + str(density8))

fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples Binary')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Max run 2048, prob. 0.01, densidad ' + str(density0))
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Max run 4096, prob. 0.01, densidad ' + str(density1))
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary')
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree')
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].set_title('Max run 8192, prob. 0.01, densidad ' + str(density2))
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary')
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Max run 2048, prob. 0.05, densidad ' + str(density3))
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary')
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Max run 4096, prob. 0.05, densidad ' + str(density4))
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary')
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree')
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack')
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast')
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].set_title('Max run 8192, prob. 0.05, densidad ' + str(density5))
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary')
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree')
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack')
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast')
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].set_title('Max run 2048, prob. 0.1, densidad ' + str(density6))
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary')
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree')
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack')
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast')
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].set_title('Max run 4096, prob. 0.1, densidad ' + str(density7))
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary')
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree')
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack')
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast')
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].set_title('Max run 8192, prob. 0.1, densidad ' + str(density8))

fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

# %% [markdown]
# ## Random Runs Select Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Selects']*100,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Selects']*100,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Selects']*100,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Selects']*100,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Selects']*100,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Selects']*100,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Selects']*100,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Selects']*100,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*100,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Selects']*100,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Selects']*100,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Selects']*100,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Selects']*100,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Selects']*100,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Selects']*100,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Selects']*100,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Selects']*100,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*100,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Selects']*100,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Selects']*100,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Selects']*100,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Selects']*100,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Selects']*100,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Selects']*100,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Selects']*100,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Selects']*100,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*100,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Selects']*100,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Selects']*100,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Selects']*100,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Selects']*100,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Selects']*100,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Selects']*100,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Selects']*100,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Selects']*100,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*100,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Selects']*100,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Selects']*100,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Selects']*100,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Selects']*100,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Selects']*100,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Selects']*100,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Selects']*100,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Selects']*100,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*100,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Selects']*100,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Selects']*100,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Selects']*100,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Selects']*100,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Selects']*100,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Selects']*100,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Selects']*100,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Selects']*100,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*100,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Selects']*100,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Selects']*100,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Selects']*100,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Selects']*100,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Selects']*100,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Selects']*100,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Selects']*100,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Selects']*100,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*100,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Selects']*100,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Selects']*100,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Selects']*100,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Selects']*100,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Selects']*100,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Selects']*100,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Selects']*100,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Selects']*100,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*100,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Selects']*100,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Selects']*100,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Selects']*100,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Selects']*100,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Selects']*100,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Selects']*100,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Selects']*100,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Selects']*100,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Selects']*100,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Selects']*100,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Selects']*100,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Selects']*100,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Selects']*100,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Selects']*100,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Selects']*100,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Selects']*100,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Selects']*100,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*100,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

fig = plt.figure(figsize=(15, 12))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
#ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples')
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree')
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack')
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR')
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast')
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast')
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].set_title('Max run 2048, prob. 0.01, densidad ' + str(density0))
#ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples')
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree')
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack')
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR')
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast')
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast')
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].set_title('Max run 4096, prob. 0.01, densidad ' + str(density1))
#ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Tuples')
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree')
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack')
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR')
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast')
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast')
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].set_title('Max run 8192, prob. 0.01, densidad ' + str(density2))
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
#ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Tuples')
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree')
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack')
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR')
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast')
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast')
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].set_title('Max run 2048, prob. 0.05, densidad ' + str(density3))
#ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Tuples')
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree')
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack')
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR')
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast')
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast')
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].set_title('Max run 4096, prob. 0.05, densidad ' + str(density4))
#ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Tuples')
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree')
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack')
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR')
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast')
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast')
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].set_title('Max run 8192, prob. 0.05, densidad ' + str(density5))
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
#ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Tuples')
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree')
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack')
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR')
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast')
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast')
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].set_title('Max run 2048, prob. 0.1, densidad ' + str(density6))
#ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Tuples')
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree')
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack')
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR')
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast')
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast')
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].set_title('Max run 4096, prob. 0.1, densidad ' + str(density7))
#ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Tuples')
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree')
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack')
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR')
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast')
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast')
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].set_title('Max run 8192, prob. 0.1, densidad ' + str(density8))

fig.supylabel('Tiempo [µs]')
fig.supxlabel('Tamaño del buffer')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

plt.show()

# %% [markdown]
# # Poisson Runs

# %% [markdown]
# ## Poisson Runs Size

# %% [markdown]
# ## Poisson Runs Insert Time

# %% [markdown]
# ## Poisson Runs Rank Time

# %% [markdown]
# ## Poisson Runs Select Time

# %% [markdown]
# # Extra

# %%
idsRandom = confIds.loc[(confIds['TestType'] == 'Random Runs') & (confIds['Probabilitie'] == 12) & (confIds['ZerosRunSize'] == 8192)]
idsRandom
# Out:
#       ID     TestType  BufferSize  Probabilitie  ZerosRunSize  OnesRunSize  \
# 43    43  Random Runs        1024          12.0          8192         8192
# 134  134  Random Runs        2048          12.0          8192         8192
# 225  225  Random Runs        4096          12.0          8192         8192
#
#      TestCount
# 43           0
# 134          0
# 225          0

# %%
tuplesLineal.head()
# Out:
#    confID   Ones   Size  Selects   Ranks  Insert Time  Random Select Time  \
# 0       0   4917  11772    49931   49879      334.904             18.3389
# 1       0  10032  21282    99914   99840      682.012             37.7701
# 2       0  14988  30792   149754  149904     1044.310             58.2774
# 3       0  19890  40302   199696  200700     1329.840             77.4310
# 4       0  24777  49812   249787  250639     1609.890             96.4286
#
#    Random Rank Time
# 0           19.5658
# 1           40.0372
# 2           61.7065
# 3           82.4087
# 4          102.5950
