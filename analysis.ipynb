# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
confIds = pd.read_csv('./configurationIds.csv', delimiter=';')

tuplesLineal = pd.read_csv('./tupleLineal.csv', delimiter=';')
tuplesInterpolation = pd.read_csv('./tupleInterpolation.csv', delimiter=';')
tuplesBinary = pd.read_csv('./tupleBinary.csv', delimiter=';')
btree = pd.read_csv('./btreeMap.csv', delimiter=';')
redBlack = pd.read_csv('./redBlackTree.csv', delimiter=';')
avl = pd.read_csv('./avlMap.csv', delimiter=';')
xfast = pd.read_csv('./xFastMap.csv', delimiter=';')
yfastUR = pd.read_csv('./yFastMapUR.csv', delimiter=';')
yfast = pd.read_csv('./yFastMapNUR.csv', delimiter=';')
sd_vectorRB = pd.read_csv('./sdVectorRandomBits.csv', delimiter=';')
sd_vectorRR = pd.read_csv('./sdVectorRandomRuns.csv', delimiter=';')
sd_vectorPR = pd.read_csv('./sdVectorPoissonRuns.csv', delimiter=';')

# %%
bufferSizes = [1024, 2048, 4096]
x = np.arange(len(bufferSizes))

# %% [markdown]
# # Random Bits

# %% [markdown]
# ## Random Bits Sizes

# %%
tuplesLineal0Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
btree0Size = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
redBlack0Size = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
avl0Size = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
xfast0Size = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
yfastUR0Size = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Size']*8/100000000,
]
yfast0Size = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Size']*8/100000000,
]

tuplesLineal1Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
btree1Size = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
redBlack1Size = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
avl1Size = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
xfast1Size = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
yfastUR1Size = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Size']*8/100000000,
]
yfast1Size = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Size']*8/100000000,
]

tuplesLineal2Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
btree2Size = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
redBlack2Size = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
avl2Size = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
xfast2Size = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
yfastUR2Size = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
yfast2Size = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Size']*8/100000000,
]
tuplesLineal3Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
btree3Size = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
redBlack3Size = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
avl3Size = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
xfast3Size = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
yfastUR3Size = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Size']*8/100000000,
]
yfast3Size = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Size']*8/100000000,
]

sd_vectorRB0Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB1Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB2Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Size']*8/100000000]*3
sd_vectorRB3Size = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Size']*8/100000000]*3

width = 0.1
fig, ax = plt.subplots(2, 2, figsize=(18, 15), sharey=False)
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.supylabel('Bits usados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Cantidad de bits utilizados por bit recibido en función de los\ndistintos tamaños de buffer para el caso de bits con distribución Bernoulli', fontsize=22, fontweight='bold')
ax[0,0].bar(x - 0.35, tuplesLineal0Size, width, label = 'tuples', color='tab:blue')
ax[0,0].bar(x - 0.25, btree0Size, width, label = 'btree', color='tab:orange')
ax[0,0].bar(x - 0.15, redBlack0Size, width, label = 'redBlack', color='tab:red')
ax[0,0].bar(x - 0.05, yfastUR0Size, width, label = 'yfastUR', color='tab:green')
ax[0,0].bar(x + 0.05, yfast0Size, width, label = 'yfast', color='tab:olive')
ax[0,0].bar(x + 0.15, xfast0Size, width, label = 'xfast', color='tab:purple')
ax[0,0].bar(x + 0.25, avl0Size, width, label = 'avl', color='tab:brown')
ax[0,0].bar(x + 0.35, sd_vectorRB0Size, width, label = 'sd vector', color='tab:pink')
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
ax[0,1].bar(x - 0.35, tuplesLineal1Size, width, label = 'tuples', color='tab:blue')
ax[0,1].bar(x - 0.25, btree1Size, width, label = 'btree', color='tab:orange')
ax[0,1].bar(x - 0.15, redBlack1Size, width, label = 'redBlack', color='tab:red')
ax[0,1].bar(x - 0.05, yfastUR1Size, width, label = 'yfastUR', color='tab:green')
ax[0,1].bar(x + 0.05, yfast1Size, width, label = 'yfast', color='tab:olive')
ax[0,1].bar(x + 0.15, xfast1Size, width, label = 'xfast', color='tab:purple')
ax[0,1].bar(x + 0.25, avl1Size, width, label = 'avl', color='tab:brown')
ax[0,1].bar(x + 0.35, sd_vectorRB1Size, width, label = 'sd vector', color='tab:pink')
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
ax[1,0].bar(x - 0.35, tuplesLineal2Size, width, label = 'tuples', color='tab:blue')
ax[1,0].bar(x - 0.25, btree2Size, width, label = 'btree', color='tab:orange')
ax[1,0].bar(x - 0.15, redBlack2Size, width, label = 'redBlack', color='tab:red')
ax[1,0].bar(x - 0.05, yfastUR2Size, width, label = 'yfastUR', color='tab:green')
ax[1,0].bar(x + 0.05, yfast2Size, width, label = 'yfast', color='tab:olive')
ax[1,0].bar(x + 0.15, xfast2Size, width, label = 'xfast', color='tab:purple')
ax[1,0].bar(x + 0.25, avl2Size, width, label = 'avl', color='tab:brown')
ax[1,0].bar(x + 0.35, sd_vectorRB2Size, width, label = 'sd vector', color='tab:pink')
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
ax[1,1].bar(x - 0.35, tuplesLineal3Size, width, label = 'tuples', color='tab:blue')
ax[1,1].bar(x - 0.25, btree3Size, width, label = 'btree', color='tab:orange')
ax[1,1].bar(x - 0.15, redBlack3Size, width, label = 'redBlack', color='tab:red')
ax[1,1].bar(x - 0.05, yfastUR3Size, width, label = 'yfastUR', color='tab:green')
ax[1,1].bar(x + 0.05, yfast3Size, width, label = 'yfast', color='tab:olive')
ax[1,1].bar(x + 0.15, xfast3Size, width, label = 'xfast', color='tab:purple')
ax[1,1].bar(x + 0.25, avl3Size, width, label = 'avl', color='tab:brown')
ax[1,1].bar(x + 0.35, sd_vectorRB3Size, width, label = 'sd vector', color='tab:pink')
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
ax[1,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight": "bold"})
plt.show()

# %% [markdown]
# ## Random Bits Insert Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ones']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido\nen función del tamaño del buffer para el caso de bits aleatorios', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(min(xfast0Time))
print(min(xfast1Time))
print(min(xfast2Time))
print(min(xfast3Time))

# %% [markdown]
# ## Random Bits Insert + Space

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ones']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ones']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal2Size, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal3Size, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido\nen función del espacio utilizado para el caso de bits con distribución Bernoulli', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(sd_vectorRB0Time)
print(sd_vectorRB1Time)
print(sd_vectorRB2Time)
print(sd_vectorRB3Time)

# %% [markdown]
# ## Random Bits Rank Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000,
]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de bits aleatorios', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de bits aleatorios', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Bits Rank + space

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000,
]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB1Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB5Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB2Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB6Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB3Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB7Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado\npara el caso de bits con distribución Bernoulli', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Bits Rank Last Million

# %%
tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 2].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 2].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 2].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 93].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 93].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 93].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 184].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 184].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 184].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 2].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 93].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 184].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 2].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 2].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 2].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 93].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 93].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 93].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 184].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 184].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 184].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 2].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 2].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 93].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 93].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 184].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 184].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 2].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 93].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 184].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 2].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 2].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 93].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 93].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 184].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 184].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 8].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 8].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 8].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 99].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 99].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 99].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 190].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 190].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 190].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 8].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 99].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 190].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 8].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 8].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 8].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 99].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 99].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 99].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 190].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 190].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 190].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 8].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 8].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 99].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 99].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 190].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 190].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 8].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 99].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 190].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 8].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 8].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 99].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 99].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 190].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 190].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 1].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 1].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 1].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 92].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 92].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 92].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 183].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 183].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 183].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 1].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 92].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 183].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 1].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 1].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 1].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 92].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 92].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 92].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 183].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 183].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 183].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 1].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 1].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 92].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 92].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 183].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 183].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 1].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 92].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 183].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 1].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 1].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 92].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 92].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 183].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 183].iloc[-2]['Ranks'])*1000,
]

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 4].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 4].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 4].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 95].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 95].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 95].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 186].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 186].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 186].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 4].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 95].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 186].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 4].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 4].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 4].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 95].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 95].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 95].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 186].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 186].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 186].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 4].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 4].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 95].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 95].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 186].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 186].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 4].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 95].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 186].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 4].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 4].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 95].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 95].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 186].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 186].iloc[-2]['Ranks'])*1000,
]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\ndurante el último millón de bits para el caso de bits aleatorios', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## random bits rank last million + space

# %%
tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 2].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 2].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 2].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 93].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 93].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 93].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 184].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 184].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 184].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 2].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 93].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 184].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 2].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 2].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 2].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 93].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 93].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 93].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 184].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 184].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 184].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 2].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 2].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 93].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 93].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 184].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 184].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 2].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 93].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 184].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 184].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 2].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 2].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 2].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 93].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 93].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 93].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 184].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 184].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 8].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 8].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 8].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 99].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 99].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 99].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 190].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 190].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 190].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 8].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 99].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 190].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 8].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 8].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 8].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 99].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 99].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 99].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 190].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 190].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 190].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 8].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 8].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 99].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 99].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 190].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 190].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 8].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 99].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 190].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 190].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 8].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 8].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 8].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 99].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 99].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 99].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 190].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 190].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 1].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 1].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 1].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 92].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 92].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 92].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 183].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 183].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 183].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 1].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 92].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 183].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 1].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 1].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 1].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 92].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 92].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 92].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 183].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 183].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 183].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 1].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 1].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 92].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 92].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 183].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 183].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 1].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 92].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 183].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 183].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 1].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 1].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 1].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 92].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 92].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 92].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 183].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 183].iloc[-2]['Ranks'])*1000,
]

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 4].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 4].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 4].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 95].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 95].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 95].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 186].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 186].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 186].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 4].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 95].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 186].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 4].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 4].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 4].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 95].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 95].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 95].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 186].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 186].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 186].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 4].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 4].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 95].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 95].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 186].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 186].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 4].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 95].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 186].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 186].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 4].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 4].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 4].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 95].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 95].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 95].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 186].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 186].iloc[-2]['Ranks'])*1000,
]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado\ndurante el último millón de bits para el caso de bits con distribución Bernoulli', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Bits Select Time

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Selects']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Selects']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Selects']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Selects']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Selects']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots(sharey=True)
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue')
ax[0,0].plot(bufferSizes, mean0Time, label = 'Extensible\nElias Fano', color='darkorange')
ax[0,0].plot(bufferSizes, sd_vectorRB0Time, label = 'sd vector', color='tab:pink')
ax[0,0].plot(bufferSizes, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples', color='tab:blue')
ax[0,1].plot(bufferSizes, mean1Time, label = 'Extensible Elias Fano', color='darkorange')
ax[0,1].plot(bufferSizes, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink')
ax[0,1].plot(bufferSizes, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesMean2Time, label = 'Tuples', color='tab:blue')
ax[1,0].plot(bufferSizes, mean2Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,0].plot(bufferSizes, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink')
ax[1,0].plot(bufferSizes, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean3Time, label = 'Tuples', color='tab:blue')
ax[1,1].plot(bufferSizes, mean3Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,1].plot(bufferSizes, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink')
ax[1,1].plot(bufferSizes, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer\npara el caso de bits aleatorios', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":12, 'weight':'bold'})

plt.show()

# %% [markdown]
# ## Random Bits select + space

# %%
tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 184].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 184].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 2].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 93].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 184].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 2].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 2].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 93].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 93].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 184].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 184].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 2].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 93].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 184].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 2].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 2].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 93].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 93].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 184].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 184].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 2].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 2].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 93].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 93].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 184].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 184].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 2].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 93].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 184].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 2].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 2].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 93].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 93].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 184].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 190].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 190].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 8].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 99].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 190].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 8].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 8].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 99].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 99].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 190].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 190].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 8].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 99].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 190].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 8].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 8].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 99].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 99].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 190].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 190].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 8].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 8].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 99].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 99].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 190].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 190].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 8].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 99].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 190].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 8].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 8].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 99].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 99].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 190].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 183].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 183].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 1].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 92].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 183].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 1].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 1].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 92].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 92].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 183].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 183].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 1].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 92].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 183].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 1].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 1].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 92].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 92].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 183].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 183].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 1].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 1].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 92].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 92].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 183].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 183].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 1].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 92].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 183].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 1].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 1].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 92].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 92].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 183].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Selects']*1000,
]

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 186].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 186].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 4].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 95].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 186].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 4].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 4].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 95].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 95].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 186].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 186].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 4].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 95].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 186].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 4].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 4].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 95].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 95].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 186].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 186].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 4].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 4].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 95].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 95].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 186].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 186].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 4].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 95].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 186].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 4].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 4].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 95].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 95].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 186].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6 )/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]

sd_vectorRB0Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Selects']*1000]*3
sd_vectorRB1Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Selects']*1000]*3
sd_vectorRB2Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Selects']*1000]*3
sd_vectorRB3Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Selects']*1000]*3

sd_vectorRB4Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.01].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 184].iloc[-1]['Ranks']*1000]*3
sd_vectorRB5Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.05].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 190].iloc[-1]['Ranks']*1000]*3
sd_vectorRB6Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.1].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 183].iloc[-1]['Ranks']*1000]*3
sd_vectorRB7Time = [sd_vectorRB.loc[sd_vectorRB['Density'] == 0.12].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 186].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(2, 2)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sd_vectorRB0Size, sd_vectorRB4Time, label = 'sd vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Densidad 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sd_vectorRB1Size, sd_vectorRB5Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Densidad 0.05', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sd_vectorRB2Size, sd_vectorRB6Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Densidad 0.1', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sd_vectorRB3Size, sd_vectorRB7Time, label = 'sd_vectorNC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Densidad 0.12', fontsize=15, fontweight='bold')
fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del espacio utilizado\npara el caso de bits con distribución Bernoulli', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# # Random Runs

# %% [markdown]
# ## Random Runs Size

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
btree0Size = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
redBlack0Size = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
avl0Size = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
xfast0Size = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
yfastUR0Size = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Size']*8/100000000,
]
yfast0Size = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Size']*8/100000000,
]

tuplesLineal1Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
btree1Size = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
redBlack1Size = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
avl1Size = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
xfast1Size = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
yfastUR1Size = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Size']*8/100000000,
]
yfast1Size = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Size']*8/100000000,
]

tuplesLineal2Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
btree2Size = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
redBlack2Size = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
avl2Size = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
xfast2Size = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
yfastUR2Size = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Size']*8/100000000,
]
yfast2Size = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Size']*8/100000000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
btree3Size = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
redBlack3Size = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
avl3Size = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
xfast3Size = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
yfastUR3Size = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Size']*8/100000000,
]
yfast3Size = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Size']*8/100000000,
]

tuplesLineal4Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
btree4Size = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
redBlack4Size = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
avl4Size = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
xfast4Size = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
yfastUR4Size = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Size']*8/100000000,
]
yfast4Size = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Size']*8/100000000,
]

tuplesLineal5Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
btree5Size = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
redBlack5Size = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
avl5Size = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
xfast5Size = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
yfastUR5Size = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Size']*8/100000000,
]
yfast5Size = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Size']*8/100000000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
btree6Size = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
redBlack6Size = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
avl6Size = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
xfast6Size = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
yfastUR6Size = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Size']*8/100000000,
]
yfast6Size = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Size']*8/100000000,
]

tuplesLineal7Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
btree7Size = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
redBlack7Size = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
avl7Size = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
xfast7Size = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
yfastUR7Size = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Size']*8/100000000,
]
yfast7Size = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Size']*8/100000000,
]

tuplesLineal8Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
btree8Size = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
redBlack8Size = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
avl8Size = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
xfast8Size = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
yfastUR8Size = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Size']*8/100000000,
]
yfast8Size = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Size']*8/100000000,
]

sdVectorRR0Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR1Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR2Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR3Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR4Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR5Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR6Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR7Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorRR8Size = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3

width = 0.1
fig, ax = plt.subplots(3, 3, figsize=(18, 15))
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.supylabel('Bits usados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Cantidad de bits utilizados por bit recibido en función de los distintos\ntamaños de buffer para el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].bar(x - 0.35, tuplesLineal0Size, width, label = 'tuples', color='tab:blue')
ax[0,0].bar(x - 0.25, btree0Size, width, label = 'btree', color='tab:orange')
ax[0,0].bar(x - 0.15, redBlack0Size, width, label = 'redBlack', color='tab:red')
ax[0,0].bar(x - 0.05, yfastUR0Size, width, label = 'yfastUR', color='tab:green')
ax[0,0].bar(x + 0.05, yfast0Size, width, label = 'yfast', color='tab:olive')
ax[0,0].bar(x + 0.15, xfast0Size, width, label = 'xfast', color='tab:purple')
ax[0,0].bar(x + 0.25, avl0Size, width, label = 'avl', color='tab:brown')
ax[0,0].bar(x + 0.35, sdVectorRR0Size, width, label = 'sd_vector', color='tab:pink')
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
ax[0,1].bar(x - 0.35, tuplesLineal1Size, width, label = 'tuples', color='tab:blue')
ax[0,1].bar(x - 0.25, btree1Size, width, label = 'btree', color='tab:orange')
ax[0,1].bar(x - 0.15, redBlack1Size, width, label = 'redBlack', color='tab:red')
ax[0,1].bar(x - 0.05, yfastUR1Size, width, label = 'yfastUR', color='tab:green')
ax[0,1].bar(x + 0.05, yfast1Size, width, label = 'yfast', color='tab:olive')
ax[0,1].bar(x + 0.15, xfast1Size, width, label = 'xfast', color='tab:purple')
ax[0,1].bar(x + 0.25, avl1Size, width, label = 'avl', color='tab:brown')
ax[0,1].bar(x + 0.35, sdVectorRR1Size, width, label = 'sd_vector', color='tab:pink')
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
ax[0,2].bar(x - 0.35, tuplesLineal2Size, width, label = 'tuples', color='tab:blue')
ax[0,2].bar(x - 0.25, btree2Size, width, label = 'btree', color='tab:orange')
ax[0,2].bar(x - 0.15, redBlack2Size, width, label = 'redBlack', color='tab:red')
ax[0,2].bar(x - 0.05, yfastUR2Size, width, label = 'yfastUR', color='tab:green')
ax[0,2].bar(x + 0.05, yfast2Size, width, label = 'yfast', color='tab:olive')
ax[0,2].bar(x + 0.15, xfast2Size, width, label = 'xfast', color='tab:purple')
ax[0,2].bar(x + 0.25, avl2Size, width, label = 'avl', color='tab:brown')
ax[0,2].bar(x + 0.35, sdVectorRR2Size, width, label = 'sd_vector', color='tab:pink')
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].set_xticks(x)
ax[0,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,2].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].bar(x - 0.35, tuplesLineal3Size, width, label = 'tuples', color='tab:blue')
ax[1,0].bar(x - 0.25, btree3Size, width, label = 'btree', color='tab:orange')
ax[1,0].bar(x - 0.15, redBlack3Size, width, label = 'redBlack', color='tab:red')
ax[1,0].bar(x - 0.05, yfastUR3Size, width, label = 'yfastUR', color='tab:green')
ax[1,0].bar(x + 0.05, yfast3Size, width, label = 'yfast', color='tab:olive')
ax[1,0].bar(x + 0.15, xfast3Size, width, label = 'xfast', color='tab:purple')
ax[1,0].bar(x + 0.25, avl3Size, width, label = 'avl', color='tab:brown')
ax[1,0].bar(x + 0.35, sdVectorRR3Size, width, label = 'sd_vector', color='tab:pink')
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
ax[1,1].bar(x - 0.35, tuplesLineal4Size, width, label = 'tuples', color='tab:blue')
ax[1,1].bar(x - 0.25, btree4Size, width, label = 'btree', color='tab:orange')
ax[1,1].bar(x - 0.15, redBlack4Size, width, label = 'redBlack', color='tab:red')
ax[1,1].bar(x - 0.05, yfastUR4Size, width, label = 'yfastUR', color='tab:green')
ax[1,1].bar(x + 0.05, yfast4Size, width, label = 'yfast', color='tab:olive')
ax[1,1].bar(x + 0.15, xfast4Size, width, label = 'xfast', color='tab:purple')
ax[1,1].bar(x + 0.25, avl4Size, width, label = 'avl', color='tab:brown')
ax[1,1].bar(x + 0.35, sdVectorRR4Size, width, label = 'sd_vector', color='tab:pink')
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
ax[1,2].bar(x - 0.35, tuplesLineal5Size, width, label = 'tuples', color='tab:blue')
ax[1,2].bar(x - 0.25, btree5Size, width, label = 'btree', color='tab:orange')
ax[1,2].bar(x - 0.15, redBlack5Size, width, label = 'redBlack', color='tab:red')
ax[1,2].bar(x - 0.05, yfastUR5Size, width, label = 'yfastUR', color='tab:green')
ax[1,2].bar(x + 0.05, yfast5Size, width, label = 'yfast', color='tab:olive')
ax[1,2].bar(x + 0.15, xfast5Size, width, label = 'xfast', color='tab:purple')
ax[1,2].bar(x + 0.25, avl5Size, width, label = 'avl', color='tab:brown')
ax[1,2].bar(x + 0.35, sdVectorRR5Size, width, label = 'sd_vector', color='tab:pink')
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].set_xticks(x)
ax[1,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,2].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].bar(x - 0.35, tuplesLineal6Size, width, label = 'tuples', color='tab:blue')
ax[2,0].bar(x - 0.25, btree6Size, width, label = 'btree', color='tab:orange')
ax[2,0].bar(x - 0.15, redBlack6Size, width, label = 'redBlack', color='tab:red')
ax[2,0].bar(x - 0.05, yfastUR6Size, width, label = 'yfastUR', color='tab:green')
ax[2,0].bar(x + 0.05, yfast6Size, width, label = 'yfast', color='tab:olive')
ax[2,0].bar(x + 0.15, xfast6Size, width, label = 'xfast', color='tab:purple')
ax[2,0].bar(x + 0.25, avl6Size, width, label = 'avl', color='tab:brown')
ax[2,0].bar(x + 0.35, sdVectorRR6Size, width, label = 'sd_vector', color='tab:pink')
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,0].set_xticks(x)
ax[2,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
ax[2,1].bar(x - 0.35, tuplesLineal7Size, width, label = 'tuples', color='tab:blue')
ax[2,1].bar(x - 0.25, btree7Size, width, label = 'btree', color='tab:orange')
ax[2,1].bar(x - 0.15, redBlack7Size, width, label = 'redBlack', color='tab:red')
ax[2,1].bar(x - 0.05, yfastUR7Size, width, label = 'yfastUR', color='tab:green')
ax[2,1].bar(x + 0.05, yfast7Size, width, label = 'yfast', color='tab:olive')
ax[2,1].bar(x + 0.15, xfast7Size, width, label = 'xfast', color='tab:purple')
ax[2,1].bar(x + 0.25, avl7Size, width, label = 'avl', color='tab:brown')
ax[2,1].bar(x + 0.35, sdVectorRR7Size, width, label = 'sd_vector', color='tab:pink')
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].set_xticks(x)
ax[2,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
ax[2,2].bar(x - 0.35, tuplesLineal8Size, width, label = 'tuples', color='tab:blue')
ax[2,2].bar(x - 0.25, btree8Size, width, label = 'btree', color='tab:orange')
ax[2,2].bar(x - 0.15, redBlack8Size, width, label = 'redBlack', color='tab:red')
ax[2,2].bar(x - 0.05, yfastUR8Size, width, label = 'yfastUR', color='tab:green')
ax[2,2].bar(x + 0.05, yfast8Size, width, label = 'yfast', color='tab:olive')
ax[2,2].bar(x + 0.15, xfast8Size, width, label = 'xfast', color='tab:purple')
ax[2,2].bar(x + 0.25, avl8Size, width, label = 'avl', color='tab:brown')
ax[2,2].bar(x + 0.35, sdVectorRR8Size, width, label = 'sd_vector', color='tab:pink')
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].set_xticks(x)
ax[2,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,2].tick_params(axis='y', labelsize=15, labelcolor="black")
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":14, "weight":"bold"})
plt.show()

# %% [markdown]
# ## Random Runs Insert Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ones']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ones']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ones']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ones']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ones']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ones']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ones']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ones']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ones']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ones']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ones']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ones']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ones']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ones']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ones']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ones']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ones']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ones']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ones']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ones']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ones']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ones']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ones']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ones']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ones']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ones']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ones']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ones']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ones']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ones']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ones']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ones']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ones']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ones']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ones']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ones']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ones']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ones']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ones']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ones']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ones']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ones']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ones']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ones']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ones']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ones']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ones']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ones']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ones']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ones']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ones']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ones']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ones']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ones']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ones']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del tamaño del buffer\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(min(xfast0Time))
print(min(xfast1Time))
print(min(xfast2Time))
print(min(xfast3Time))
print(min(xfast4Time))
print(min(xfast5Time))
print(min(xfast6Time))
print(min(xfast7Time))
print(min(xfast8Time))

# %% [markdown]
# ## Random Runs inser + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ones']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ones']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ones']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ones']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ones']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ones']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ones']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ones']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ones']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ones']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ones']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ones']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ones']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ones']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ones']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ones']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ones']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ones']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ones']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ones']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ones']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ones']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ones']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ones']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ones']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ones']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ones']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ones']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ones']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ones']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ones']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ones']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ones']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ones']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ones']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ones']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ones']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ones']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ones']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ones']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ones']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ones']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ones']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ones']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ones']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ones']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ones']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ones']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ones']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ones']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ones']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ones']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ones']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ones']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ones']*1000]*3

tuplesLineal0Size.sort()
btree0Size.sort()
redBlack0Size.sort()
yfastUR0Size.sort()
yfast0Size.sort()
xfast0Size.sort()
avl0Size.sort()
tuplesLineal1Size.sort()
btree1Size.sort()
redBlack1Size.sort()
yfastUR1Size.sort()
yfast1Size.sort()
xfast1Size.sort()
avl1Size.sort()
tuplesLineal2Size.sort()
btree2Size.sort()
redBlack2Size.sort()
yfastUR2Size.sort()
yfast2Size.sort()
xfast2Size.sort()
avl2Size.sort()
tuplesLineal3Size.sort()
btree3Size.sort()
redBlack3Size.sort()
yfastUR3Size.sort()
yfast3Size.sort()
xfast3Size.sort()
avl3Size.sort()
tuplesLineal4Size.sort()
btree4Size.sort()
redBlack4Size.sort()
yfastUR4Size.sort()
yfast4Size.sort()
xfast4Size.sort()
avl4Size.sort()
tuplesLineal5Size.sort()
btree5Size.sort()
redBlack5Size.sort()
yfastUR5Size.sort()
yfast5Size.sort()
xfast5Size.sort()
avl5Size.sort()
tuplesLineal6Size.sort()
btree6Size.sort()
redBlack6Size.sort()
yfastUR6Size.sort()
yfast6Size.sort()
xfast6Size.sort()
avl6Size.sort()
tuplesLineal7Size.sort()
btree7Size.sort()
redBlack7Size.sort()
yfastUR7Size.sort()
yfast7Size.sort()
xfast7Size.sort()
avl7Size.sort()
tuplesLineal8Size.sort()
btree8Size.sort()
redBlack8Size.sort()
yfastUR8Size.sort()
yfast8Size.sort()
xfast8Size.sort()
avl8Size.sort()

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal3Size, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesMean4Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesMean5Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].plot(tuplesLineal6Size, tuplesMean6Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesMean7Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesMean8Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del espacio utilizado\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(sdVectorRR0Time)
print(sdVectorRR1Time)
print(sdVectorRR2Time)
print(sdVectorRR3Time)
print(sdVectorRR4Time)
print(sdVectorRR5Time)
print(sdVectorRR6Time)
print(sdVectorRR7Time)
print(sdVectorRR8Time)

# %% [markdown]
# ## Random Runs Rank Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ranks']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ranks']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ranks']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ranks']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ranks']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ranks']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ranks']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ranks']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ranks']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ranks']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ranks']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ranks']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ranks']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ranks']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ranks']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ranks']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ranks']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ranks']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ranks']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ranks']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ranks']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ranks']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ranks']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ranks']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ranks']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ranks']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ranks']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ranks']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ranks']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ranks']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ranks']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ranks']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ranks']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ranks']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ranks']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000,
]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Runs Rank + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ranks']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ranks']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Ranks']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ranks']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Ranks']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Ranks']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ranks']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ranks']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ranks']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Ranks']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ranks']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Ranks']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Ranks']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ranks']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ranks']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ranks']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Ranks']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ranks']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Ranks']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Ranks']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ranks']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ranks']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ranks']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Ranks']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ranks']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Ranks']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Ranks']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ranks']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ranks']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ranks']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Ranks']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ranks']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Ranks']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Ranks']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ranks']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000,
]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Runs Rank Time Last Million

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 15].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 15].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 15].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 106].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 106].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 106].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 197].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 197].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 197].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 15].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 106].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 197].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 15].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 15].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 15].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 106].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 106].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 106].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 197].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 197].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 197].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 15].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 15].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 106].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 106].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 197].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 197].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 15].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 106].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 197].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 15].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 15].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 106].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 106].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 197].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 197].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 28].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 28].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 28].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 119].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 119].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 119].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 210].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 210].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 210].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 28].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 119].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 210].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 28].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 28].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 28].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 119].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 119].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 119].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 210].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 210].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 210].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 28].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 28].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 119].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 119].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 210].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 210].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 28].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 119].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 210].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 28].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 28].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 119].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 119].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 210].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 210].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 41].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 41].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 41].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 132].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 132].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 132].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 223].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 223].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 223].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 41].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 132].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 223].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 41].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 41].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 41].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 132].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 132].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 132].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 223].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 223].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 223].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 41].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 41].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 132].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 132].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 223].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 223].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 41].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 132].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 223].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 41].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 41].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 132].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 132].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 223].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 223].iloc[-2]['Ranks'])*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 21].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 21].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 21].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 112].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 112].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 112].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 203].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 203].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 203].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 21].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 112].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 203].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 21].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 21].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 21].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 112].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 112].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 112].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 203].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 203].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 203].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 21].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 21].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 112].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 112].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 203].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 203].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 21].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 112].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 203].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 21].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 21].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 112].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 112].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 203].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 203].iloc[-2]['Ranks'])*1000,
]

tuplesLineal4Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation4Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
tuplesBinary4Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
btree4Time = [
  (btree.loc[btree['confID'] == 34].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 34].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 34].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 125].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 125].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 125].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 216].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 216].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 216].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
redBlack4Time = [
  (redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 34].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 125].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 216].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
avl4Time = [
  (avl.loc[avl['confID'] == 34].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 34].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 34].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 125].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 125].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 125].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 216].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 216].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 216].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
xfast4Time = [
  (xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 34].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 34].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 125].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 125].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 216].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 216].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
yfastUR4Time = [
  (yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 34].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 125].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 216].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
yfast4Time = [
  (yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 34].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 34].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 125].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 125].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 216].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 216].iloc[-2]['Ranks'])*1000,
]

tuplesLineal5Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation5Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
tuplesBinary5Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
btree5Time = [
  (btree.loc[btree['confID'] == 47].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 47].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 47].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 138].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 138].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 138].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 229].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 229].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 229].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
redBlack5Time = [
  (redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 47].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 138].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 229].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
avl5Time = [
  (avl.loc[avl['confID'] == 47].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 47].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 47].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 138].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 138].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 138].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 229].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 229].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 229].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
xfast5Time = [
  (xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 47].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 47].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 138].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 138].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 229].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 229].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
yfastUR5Time = [
  (yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 47].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 138].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 229].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
yfast5Time = [
  (yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 47].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 47].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 138].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 138].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 229].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 229].iloc[-2]['Ranks'])*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation6Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
tuplesBinary6Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
btree6Time = [
  (btree.loc[btree['confID'] == 14].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 14].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 14].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 105].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 105].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 105].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 196].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 196].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 196].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
redBlack6Time = [
  (redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 14].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 105].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 196].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
avl6Time = [
  (avl.loc[avl['confID'] == 14].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 14].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 14].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 105].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 105].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 105].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 196].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 196].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 196].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
xfast6Time = [
  (xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 14].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 14].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 105].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 105].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 196].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 196].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
yfastUR6Time = [
  (yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 14].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 105].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 196].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
yfast6Time = [
  (yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 14].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 14].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 105].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 105].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 196].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 196].iloc[-2]['Ranks'])*1000,
]

tuplesLineal7Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation7Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
tuplesBinary7Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
btree7Time = [
  (btree.loc[btree['confID'] == 27].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 27].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 27].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 118].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 118].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 118].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 209].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 209].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 209].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
redBlack7Time = [
  (redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 27].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 118].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 209].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
avl7Time = [
  (avl.loc[avl['confID'] == 27].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 27].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 27].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 118].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 118].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 118].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 209].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 209].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 209].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
xfast7Time = [
  (xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 27].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 27].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 118].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 118].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 209].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 209].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
yfastUR7Time = [
  (yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 27].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 118].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 209].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
yfast7Time = [
  (yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 27].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 27].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 118].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 118].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 209].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 209].iloc[-2]['Ranks'])*1000,
]

tuplesLineal8Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation8Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
tuplesBinary8Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
btree8Time = [
  (btree.loc[btree['confID'] == 40].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 40].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 40].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 131].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 131].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 131].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 222].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 222].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 222].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
redBlack8Time = [
  (redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 40].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 131].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 222].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
avl8Time = [
  (avl.loc[avl['confID'] == 40].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 40].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 40].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 131].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 131].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 131].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 222].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 222].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 222].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
xfast8Time = [
  (xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 40].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 40].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 131].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 131].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 222].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 222].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
yfastUR8Time = [
  (yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 40].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 131].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 222].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
yfast8Time = [
  (yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 40].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 40].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 131].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 131].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 222].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 222].iloc[-2]['Ranks'])*1000,
]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer durante\nel último millón de bits para el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random runs rank last million + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 15].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 15].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 15].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 106].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 106].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 106].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 197].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 197].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 197].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 15].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 106].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 197].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 15].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 15].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 15].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 106].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 106].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 106].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 197].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 197].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 197].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 15].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 15].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 106].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 106].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 197].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 197].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 15].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 106].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 197].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 197].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 15].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 15].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 15].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 106].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 106].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 106].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 197].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 197].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 28].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 28].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 28].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 119].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 119].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 119].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 210].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 210].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 210].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 28].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 119].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 210].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 28].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 28].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 28].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 119].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 119].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 119].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 210].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 210].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 210].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 28].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 28].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 119].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 119].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 210].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 210].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 28].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 119].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 210].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 210].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 28].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 28].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 28].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 119].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 119].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 119].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 210].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 210].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 41].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 41].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 41].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 132].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 132].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 132].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 223].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 223].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 223].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 41].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 132].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 223].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 41].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 41].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 41].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 132].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 132].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 132].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 223].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 223].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 223].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 41].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 41].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 132].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 132].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 223].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 223].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 41].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 132].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 223].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 223].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 41].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 41].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 41].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 132].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 132].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 132].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 223].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 223].iloc[-2]['Ranks'])*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 21].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 21].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 21].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 112].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 112].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 112].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 203].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 203].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 203].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 21].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 112].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 203].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 21].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 21].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 21].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 112].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 112].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 112].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 203].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 203].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 203].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 21].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 21].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 112].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 112].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 203].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 203].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 21].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 112].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 203].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 203].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 21].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 21].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 21].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 112].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 112].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 112].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 203].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 203].iloc[-2]['Ranks'])*1000,
]

tuplesLineal4Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation4Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
tuplesBinary4Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
btree4Time = [
  (btree.loc[btree['confID'] == 34].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 34].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 34].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 125].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 125].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 125].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 216].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 216].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 216].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
redBlack4Time = [
  (redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 34].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 125].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 216].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
avl4Time = [
  (avl.loc[avl['confID'] == 34].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 34].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 34].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 125].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 125].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 125].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 216].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 216].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 216].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
xfast4Time = [
  (xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 34].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 34].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 125].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 125].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 216].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 216].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
yfastUR4Time = [
  (yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 34].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 125].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 216].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 216].iloc[-2]['Ranks'])*1000,
]
yfast4Time = [
  (yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 34].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 34].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 34].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 125].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 125].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 125].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 216].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 216].iloc[-2]['Ranks'])*1000,
]

tuplesLineal5Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation5Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
tuplesBinary5Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
btree5Time = [
  (btree.loc[btree['confID'] == 47].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 47].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 47].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 138].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 138].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 138].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 229].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 229].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 229].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
redBlack5Time = [
  (redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 47].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 138].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 229].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
avl5Time = [
  (avl.loc[avl['confID'] == 47].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 47].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 47].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 138].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 138].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 138].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 229].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 229].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 229].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
xfast5Time = [
  (xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 47].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 47].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 138].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 138].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 229].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 229].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
yfastUR5Time = [
  (yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 47].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 138].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 229].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 229].iloc[-2]['Ranks'])*1000,
]
yfast5Time = [
  (yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 47].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 47].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 47].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 138].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 138].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 138].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 229].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 229].iloc[-2]['Ranks'])*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation6Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
tuplesBinary6Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
btree6Time = [
  (btree.loc[btree['confID'] == 14].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 14].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 14].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 105].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 105].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 105].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 196].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 196].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 196].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
redBlack6Time = [
  (redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 14].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 105].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 196].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
avl6Time = [
  (avl.loc[avl['confID'] == 14].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 14].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 14].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 105].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 105].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 105].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 196].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 196].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 196].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
xfast6Time = [
  (xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 14].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 14].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 105].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 105].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 196].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 196].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
yfastUR6Time = [
  (yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 14].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 105].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 196].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 196].iloc[-2]['Ranks'])*1000,
]
yfast6Time = [
  (yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 14].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 14].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 14].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 105].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 105].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 105].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 196].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 196].iloc[-2]['Ranks'])*1000,
]

tuplesLineal7Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation7Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
tuplesBinary7Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
btree7Time = [
  (btree.loc[btree['confID'] == 27].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 27].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 27].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 118].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 118].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 118].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 209].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 209].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 209].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
redBlack7Time = [
  (redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 27].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 118].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 209].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
avl7Time = [
  (avl.loc[avl['confID'] == 27].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 27].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 27].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 118].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 118].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 118].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 209].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 209].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 209].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
xfast7Time = [
  (xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 27].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 27].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 118].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 118].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 209].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 209].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
yfastUR7Time = [
  (yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 27].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 118].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 209].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 209].iloc[-2]['Ranks'])*1000,
]
yfast7Time = [
  (yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 27].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 27].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 27].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 118].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 118].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 118].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 209].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 209].iloc[-2]['Ranks'])*1000,
]

tuplesLineal8Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation8Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
tuplesBinary8Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
btree8Time = [
  (btree.loc[btree['confID'] == 40].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 40].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 40].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 131].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 131].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 131].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 222].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 222].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 222].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
redBlack8Time = [
  (redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 40].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 131].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 222].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
avl8Time = [
  (avl.loc[avl['confID'] == 40].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 40].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 40].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 131].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 131].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 131].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 222].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 222].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 222].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
xfast8Time = [
  (xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 40].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 40].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 131].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 131].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 222].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 222].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
yfastUR8Time = [
  (yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 40].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 131].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 222].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 222].iloc[-2]['Ranks'])*1000,
]
yfast8Time = [
  (yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 40].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 40].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 40].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 131].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 131].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 131].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 222].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 222].iloc[-2]['Ranks'])*1000,
]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Ranks']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Ranks']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Ranks']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Ranks']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Ranks']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Ranks']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Ranks']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Ranks']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado durante\nel último millón de bits para el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Random Runs Select Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Selects']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Selects']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Selects']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Selects']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Selects']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Selects']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Selects']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Selects']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Selects']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Selects']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Selects']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Selects']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Selects']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Selects']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Selects']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Selects']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Selects']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Selects']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Selects']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Selects']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Selects']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Selects']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Selects']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Selects']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Selects']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Selects']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Selects']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Selects']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Selects']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Selects']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Selects']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Selects']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Selects']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Selects']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Selects']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Selects']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Selects']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Selects']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Selects']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Selects']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]
mean4Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree4Time, redBlack4Time, avl4Time, xfast4Time, yfastUR4Time, yfast4Time)]
mean5Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree5Time, redBlack5Time, avl5Time, xfast5Time, yfastUR5Time, yfast5Time)]
mean6Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree6Time, redBlack6Time, avl6Time, xfast6Time, yfastUR6Time, yfast6Time)]
mean7Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree7Time, redBlack7Time, avl7Time, xfast7Time, yfastUR7Time, yfast7Time)]
mean8Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree8Time, redBlack8Time, avl8Time, xfast8Time, yfastUR8Time, yfast8Time)]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue')
ax[0,0].plot(bufferSizes, mean0Time, label = 'Extensible\nElias Fano', color='darkorange')
ax[0,0].plot(bufferSizes, sdVectorRR0Time, label = 'sd vector', color='tab:pink')
ax[0,0].plot(bufferSizes, sdVectorRR9Time, label = 'sd vectorNC', color='indigo')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[0,1].plot(bufferSizes, mean1Time, label = 'Extensible Elias Fano', color='darkorange')
ax[0,1].plot(bufferSizes, sdVectorRR1Time, label = 'sd_vector', color='tab:pink')
ax[0,1].plot(bufferSizes, sdVectorRR10Time, label = 'sd_vectorNC', color='indigo')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[0,2].plot(bufferSizes, mean2Time, label = 'Extensible Elias Fano', color='darkorange')
ax[0,2].plot(bufferSizes, sdVectorRR2Time, label = 'sd_vector', color='tab:pink')
ax[0,2].plot(bufferSizes, sdVectorRR11Time, label = 'sd_vectorNC', color='indigo')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,0].plot(bufferSizes, mean3Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,0].plot(bufferSizes, sdVectorRR3Time, label = 'sd_vector', color='tab:pink')
ax[1,0].plot(bufferSizes, sdVectorRR12Time, label = 'sd_vectorNC', color='indigo')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,1].plot(bufferSizes, mean4Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,1].plot(bufferSizes, sdVectorRR4Time, label = 'sd_vector', color='tab:pink')
ax[1,1].plot(bufferSizes, sdVectorRR13Time, label = 'sd_vectorNC', color='indigo')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,2].plot(bufferSizes, mean5Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,2].plot(bufferSizes, sdVectorRR5Time, label = 'sd_vector', color='tab:pink')
ax[1,2].plot(bufferSizes, sdVectorRR14Time, label = 'sd_vectorNC', color='indigo')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,0].plot(bufferSizes, mean6Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,0].plot(bufferSizes, sdVectorRR6Time, label = 'sd_vector', color='tab:pink')
ax[2,0].plot(bufferSizes, sdVectorRR15Time, label = 'sd_vectorNC', color='indigo')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,1].plot(bufferSizes, mean7Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,1].plot(bufferSizes, sdVectorRR7Time, label = 'sd_vector', color='tab:pink')
ax[2,1].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vectorNC', color='indigo')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,2].plot(bufferSizes, mean8Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,2].plot(bufferSizes, sdVectorRR8Time, label = 'sd_vector', color='tab:pink')
ax[2,2].plot(bufferSizes, sdVectorRR16Time, label = 'sd_vectorNC', color='indigo')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":12, 'weight':'bold'})

plt.show()

# %% [markdown]
# ## Random Runs select + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 197].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 197].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 15].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 106].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 197].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 15].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 15].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 106].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 106].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 197].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 197].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 15].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 106].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 197].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 15].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 15].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 106].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 106].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 197].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 197].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 15].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 15].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 106].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 106].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 197].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 197].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 15].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 106].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 197].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 15].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 15].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 106].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 106].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 197].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 210].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 210].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 28].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 119].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 210].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 28].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 28].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 119].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 119].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 210].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 210].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 28].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 119].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 210].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 28].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 28].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 119].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 119].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 210].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 210].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 28].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 28].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 119].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 119].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 210].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 210].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 28].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 119].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 210].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 28].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 28].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 119].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 119].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 210].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 223].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 223].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 41].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 132].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 223].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 41].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 41].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 132].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 132].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 223].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 223].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 41].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 132].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 223].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 41].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 41].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 132].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 132].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 223].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 223].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 41].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 41].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 132].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 132].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 223].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 223].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 41].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 132].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 223].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 41].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 41].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 132].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 132].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 223].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 203].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 203].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 21].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 112].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 203].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 21].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 21].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 112].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 112].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 203].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 203].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 21].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 112].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 203].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 21].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 21].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 112].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 112].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 203].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 203].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 21].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 21].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 112].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 112].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 203].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 203].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 21].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 112].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 203].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 21].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 21].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 112].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 112].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 203].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 216].iloc[-1]['Selects']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 216].iloc[-1]['Selects']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 34].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 125].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 216].iloc[-1]['Selects']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 34].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 34].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 125].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 125].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 216].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 216].iloc[-1]['Selects']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 34].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 125].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 216].iloc[-1]['Selects']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 34].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 34].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 125].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 125].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 216].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 216].iloc[-1]['Selects']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 34].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 34].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 125].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 125].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 216].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 216].iloc[-1]['Selects']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 34].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 125].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 216].iloc[-1]['Selects']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 34].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 34].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 125].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 125].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 216].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 229].iloc[-1]['Selects']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 229].iloc[-1]['Selects']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 47].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 138].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 229].iloc[-1]['Selects']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 47].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 47].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 138].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 138].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 229].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 229].iloc[-1]['Selects']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 47].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 138].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 229].iloc[-1]['Selects']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 47].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 47].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 138].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 138].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 229].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 229].iloc[-1]['Selects']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 47].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 47].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 138].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 138].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 229].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 229].iloc[-1]['Selects']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 47].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 138].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 229].iloc[-1]['Selects']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 47].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 47].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 138].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 138].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 229].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 196].iloc[-1]['Selects']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 196].iloc[-1]['Selects']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 14].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 105].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 196].iloc[-1]['Selects']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 14].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 14].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 105].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 105].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 196].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 196].iloc[-1]['Selects']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 14].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 105].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 196].iloc[-1]['Selects']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 14].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 14].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 105].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 105].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 196].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 196].iloc[-1]['Selects']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 14].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 14].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 105].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 105].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 196].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 196].iloc[-1]['Selects']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 14].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 105].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 196].iloc[-1]['Selects']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 14].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 14].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 105].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 105].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 196].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 209].iloc[-1]['Selects']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 209].iloc[-1]['Selects']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 27].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 118].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 209].iloc[-1]['Selects']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 27].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 27].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 118].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 118].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 209].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 209].iloc[-1]['Selects']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 27].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 118].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 209].iloc[-1]['Selects']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 27].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 27].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 118].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 118].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 209].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 209].iloc[-1]['Selects']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 27].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 27].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 118].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 118].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 209].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 209].iloc[-1]['Selects']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 27].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 118].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 209].iloc[-1]['Selects']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 27].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 27].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 118].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 118].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 209].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 222].iloc[-1]['Selects']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 222].iloc[-1]['Selects']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 40].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 131].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 222].iloc[-1]['Selects']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 40].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 40].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 131].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 131].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 222].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 222].iloc[-1]['Selects']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 40].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 131].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 222].iloc[-1]['Selects']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 40].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 40].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 131].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 131].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 222].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 222].iloc[-1]['Selects']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 40].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 40].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 131].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 131].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 222].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 222].iloc[-1]['Selects']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 40].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 131].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 222].iloc[-1]['Selects']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 40].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 40].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 131].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 131].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 222].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]
mean4Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree4Time, redBlack4Time, avl4Time, xfast4Time, yfastUR4Time, yfast4Time)]
mean5Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree5Time, redBlack5Time, avl5Time, xfast5Time, yfastUR5Time, yfast5Time)]
mean6Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree6Time, redBlack6Time, avl6Time, xfast6Time, yfastUR6Time, yfast6Time)]
mean7Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree7Time, redBlack7Time, avl7Time, xfast7Time, yfastUR7Time, yfast7Time)]
mean8Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree8Time, redBlack8Time, avl8Time, xfast8Time, yfastUR8Time, yfast8Time)]

sdVectorRR0Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000]*3
sdVectorRR1Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000]*3
sdVectorRR2Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000]*3
sdVectorRR3Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000]*3
sdVectorRR4Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000]*3
sdVectorRR5Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000]*3
sdVectorRR6Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000]*3
sdVectorRR7Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000]*3
sdVectorRR8Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000]*3
sdVectorRR9Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 197].iloc[-1]['Selects']*1000]*3
sdVectorRR10Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 210].iloc[-1]['Selects']*1000]*3
sdVectorRR11Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.01) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 223].iloc[-1]['Selects']*1000]*3
sdVectorRR12Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 203].iloc[-1]['Selects']*1000]*3
sdVectorRR13Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 216].iloc[-1]['Selects']*1000]*3
sdVectorRR14Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.05) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 229].iloc[-1]['Selects']*1000]*3
sdVectorRR15Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 196].iloc[-1]['Selects']*1000]*3
sdVectorRR16Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 209].iloc[-1]['Selects']*1000]*3
sdVectorRR17Time = [sd_vectorRR.loc[(sd_vectorRR['Density'] == 0.1) & (sd_vectorRR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 222].iloc[-1]['Selects']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del espacio utilizado\npara el caso de secuencias con distribución uniforme', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":12, 'weight':'bold'})

plt.show()

# %% [markdown]
# # Poisson Runs

# %% [markdown]
# ## Poisson Runs Size

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
btree0Size = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
redBlack0Size = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
avl0Size = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
xfast0Size = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
yfastUR0Size = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Size']*8/100000000,
]
yfast0Size = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Size']*8/100000000,
]

tuplesLineal1Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
btree1Size = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
redBlack1Size = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
avl1Size = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
xfast1Size = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
yfastUR1Size = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Size']*8/100000000,
]
yfast1Size = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Size']*8/100000000,
]

tuplesLineal2Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
btree2Size = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
redBlack2Size = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
avl2Size = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
xfast2Size = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
yfastUR2Size = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Size']*8/100000000,
]
yfast2Size = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Size']*8/100000000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
btree3Size = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
redBlack3Size = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
avl3Size = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
xfast3Size = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
yfastUR3Size = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Size']*8/100000000,
]
yfast3Size = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Size']*8/100000000,
]

tuplesLineal4Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
btree4Size = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
redBlack4Size = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
avl4Size = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
xfast4Size = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
yfastUR4Size = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Size']*8/100000000,
]
yfast4Size = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Size']*8/100000000,
]

tuplesLineal5Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
btree5Size = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
redBlack5Size = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
avl5Size = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
xfast5Size = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
yfastUR5Size = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Size']*8/100000000,
]
yfast5Size = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Size']*8/100000000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
btree6Size = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
redBlack6Size = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
avl6Size = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
xfast6Size = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
yfastUR6Size = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Size']*8/100000000,
]
yfast6Size = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Size']*8/100000000,
]

tuplesLineal7Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
btree7Size = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
redBlack7Size = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
avl7Size = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
xfast7Size = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
yfastUR7Size = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Size']*8/100000000,
]
yfast7Size = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Size']*8/100000000,
]

tuplesLineal8Size = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Size']*8/100000000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
btree8Size = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Size']*8/100000000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
redBlack8Size = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Size']*8/100000000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
avl8Size = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Size']*8/100000000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
xfast8Size = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Size']*8/100000000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
yfastUR8Size = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Size']*8/100000000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Size']*8/100000000,
]
yfast8Size = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Size']*8/100000000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Size']*8/100000000,
]

sdVectorPR0Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR1Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR2Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR3Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR4Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR5Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR6Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR7Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Size']*8/100000000]*3
sdVectorPR8Size = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Size']*8/100000000]*3

width = 0.1
fig, ax = plt.subplots(3, 3, figsize=(18, 15))
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.supylabel('Bits usados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Cantidad de bits utilizados por bit recibido en función de los distintos\ntamaños de buffer para el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].bar(x - 0.35, tuplesLineal0Size, width, label = 'tuples', color='tab:blue')
ax[0,0].bar(x - 0.25, btree0Size, width, label = 'btree', color='tab:orange')
ax[0,0].bar(x - 0.15, redBlack0Size, width, label = 'redBlack', color='tab:red')
ax[0,0].bar(x - 0.05, yfastUR0Size, width, label = 'yfastUR', color='tab:green')
ax[0,0].bar(x + 0.05, yfast0Size, width, label = 'yfast', color='tab:olive')
ax[0,0].bar(x + 0.15, xfast0Size, width, label = 'xfast', color='tab:purple')
ax[0,0].bar(x + 0.25, avl0Size, width, label = 'avl', color='tab:brown')
ax[0,0].bar(x + 0.35, sdVectorRR0Size, width, label = 'sd_vector', color='tab:pink')
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
ax[0,1].bar(x - 0.35, tuplesLineal1Size, width, label = 'tuples', color='tab:blue')
ax[0,1].bar(x - 0.25, btree1Size, width, label = 'btree', color='tab:orange')
ax[0,1].bar(x - 0.15, redBlack1Size, width, label = 'redBlack', color='tab:red')
ax[0,1].bar(x - 0.05, yfastUR1Size, width, label = 'yfastUR', color='tab:green')
ax[0,1].bar(x + 0.05, yfast1Size, width, label = 'yfast', color='tab:olive')
ax[0,1].bar(x + 0.15, xfast1Size, width, label = 'xfast', color='tab:purple')
ax[0,1].bar(x + 0.25, avl1Size, width, label = 'avl', color='tab:brown')
ax[0,1].bar(x + 0.35, sdVectorRR1Size, width, label = 'sd_vector', color='tab:pink')
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].set_xticks(x)
ax[0,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
ax[0,2].bar(x - 0.35, tuplesLineal2Size, width, label = 'tuples', color='tab:blue')
ax[0,2].bar(x - 0.25, btree2Size, width, label = 'btree', color='tab:orange')
ax[0,2].bar(x - 0.15, redBlack2Size, width, label = 'redBlack', color='tab:red')
ax[0,2].bar(x - 0.05, yfastUR2Size, width, label = 'yfastUR', color='tab:green')
ax[0,2].bar(x + 0.05, yfast2Size, width, label = 'yfast', color='tab:olive')
ax[0,2].bar(x + 0.15, xfast2Size, width, label = 'xfast', color='tab:purple')
ax[0,2].bar(x + 0.25, avl2Size, width, label = 'avl', color='tab:brown')
ax[0,2].bar(x + 0.35, sdVectorRR2Size, width, label = 'sd_vector', color='tab:pink')
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].set_xticks(x)
ax[0,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[0,2].tick_params(axis='y', labelsize=15)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].bar(x - 0.35, tuplesLineal3Size, width, label = 'tuples', color='tab:blue')
ax[1,0].bar(x - 0.25, btree3Size, width, label = 'btree', color='tab:orange')
ax[1,0].bar(x - 0.15, redBlack3Size, width, label = 'redBlack', color='tab:red')
ax[1,0].bar(x - 0.05, yfastUR3Size, width, label = 'yfastUR', color='tab:green')
ax[1,0].bar(x + 0.05, yfast3Size, width, label = 'yfast', color='tab:olive')
ax[1,0].bar(x + 0.15, xfast3Size, width, label = 'xfast', color='tab:purple')
ax[1,0].bar(x + 0.25, avl3Size, width, label = 'avl', color='tab:brown')
ax[1,0].bar(x + 0.35, sdVectorRR3Size, width, label = 'sd_vector', color='tab:pink')
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,0].set_xticks(x)
ax[1,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
ax[1,1].bar(x - 0.35, tuplesLineal4Size, width, label = 'tuples', color='tab:blue')
ax[1,1].bar(x - 0.25, btree4Size, width, label = 'btree', color='tab:orange')
ax[1,1].bar(x - 0.15, redBlack4Size, width, label = 'redBlack', color='tab:red')
ax[1,1].bar(x - 0.05, yfastUR4Size, width, label = 'yfastUR', color='tab:green')
ax[1,1].bar(x + 0.05, yfast4Size, width, label = 'yfast', color='tab:olive')
ax[1,1].bar(x + 0.15, xfast4Size, width, label = 'xfast', color='tab:purple')
ax[1,1].bar(x + 0.25, avl4Size, width, label = 'avl', color='tab:brown')
ax[1,1].bar(x + 0.35, sdVectorRR4Size, width, label = 'sd_vector', color='tab:pink')
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].set_xticks(x)
ax[1,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
ax[1,2].bar(x - 0.35, tuplesLineal5Size, width, label = 'tuples', color='tab:blue')
ax[1,2].bar(x - 0.25, btree5Size, width, label = 'btree', color='tab:orange')
ax[1,2].bar(x - 0.15, redBlack5Size, width, label = 'redBlack', color='tab:red')
ax[1,2].bar(x - 0.05, yfastUR5Size, width, label = 'yfastUR', color='tab:green')
ax[1,2].bar(x + 0.05, yfast5Size, width, label = 'yfast', color='tab:olive')
ax[1,2].bar(x + 0.15, xfast5Size, width, label = 'xfast', color='tab:purple')
ax[1,2].bar(x + 0.25, avl5Size, width, label = 'avl', color='tab:brown')
ax[1,2].bar(x + 0.35, sdVectorRR5Size, width, label = 'sd_vector', color='tab:pink')
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].set_xticks(x)
ax[1,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[1,2].tick_params(axis='y', labelsize=15)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].bar(x - 0.35, tuplesLineal6Size, width, label = 'tuples', color='tab:blue')
ax[2,0].bar(x - 0.25, btree6Size, width, label = 'btree', color='tab:orange')
ax[2,0].bar(x - 0.15, redBlack6Size, width, label = 'redBlack', color='tab:red')
ax[2,0].bar(x - 0.05, yfastUR6Size, width, label = 'yfastUR', color='tab:green')
ax[2,0].bar(x + 0.05, yfast6Size, width, label = 'yfast', color='tab:olive')
ax[2,0].bar(x + 0.15, xfast6Size, width, label = 'xfast', color='tab:purple')
ax[2,0].bar(x + 0.25, avl6Size, width, label = 'avl', color='tab:brown')
ax[2,0].bar(x + 0.35, sdVectorRR6Size, width, label = 'sd_vector', color='tab:pink')
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,0].set_xticks(x)
ax[2,0].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,0].tick_params(axis='y', labelsize=15)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
ax[2,1].bar(x - 0.35, tuplesLineal7Size, width, label = 'tuples', color='tab:blue')
ax[2,1].bar(x - 0.25, btree7Size, width, label = 'btree', color='tab:orange')
ax[2,1].bar(x - 0.15, redBlack7Size, width, label = 'redBlack', color='tab:red')
ax[2,1].bar(x - 0.05, yfastUR7Size, width, label = 'yfastUR', color='tab:green')
ax[2,1].bar(x + 0.05, yfast7Size, width, label = 'yfast', color='tab:olive')
ax[2,1].bar(x + 0.15, xfast7Size, width, label = 'xfast', color='tab:purple')
ax[2,1].bar(x + 0.25, avl7Size, width, label = 'avl', color='tab:brown')
ax[2,1].bar(x + 0.35, sdVectorRR7Size, width, label = 'sd_vector', color='tab:pink')
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].set_xticks(x)
ax[2,1].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,1].tick_params(axis='y', labelsize=15)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
ax[2,2].bar(x - 0.35, tuplesLineal8Size, width, label = 'tuples', color='tab:blue')
ax[2,2].bar(x - 0.25, btree8Size, width, label = 'btree', color='tab:orange')
ax[2,2].bar(x - 0.15, redBlack8Size, width, label = 'redBlack', color='tab:red')
ax[2,2].bar(x - 0.05, yfastUR8Size, width, label = 'yfastUR', color='tab:green')
ax[2,2].bar(x + 0.05, yfast8Size, width, label = 'yfast', color='tab:olive')
ax[2,2].bar(x + 0.15, xfast8Size, width, label = 'xfast', color='tab:purple')
ax[2,2].bar(x + 0.25, avl8Size, width, label = 'avl', color='tab:brown')
ax[2,2].bar(x + 0.35, sdVectorRR8Size, width, label = 'sd_vector', color='tab:pink')
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].set_xticks(x)
ax[2,2].set_xticklabels(bufferSizes, fontsize=15, fontweight='bold')
ax[2,2].tick_params(axis='y', labelsize=15, labelcolor="black")
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":14, "weight":"bold"})
plt.show()

# %% [markdown]
# ## Poisson Runs Insert Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ones']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ones']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ones']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ones']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ones']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Ones']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ones']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Ones']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Ones']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ones']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ones']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ones']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ones']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ones']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Ones']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ones']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Ones']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Ones']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ones']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ones']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ones']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ones']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ones']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Ones']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ones']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Ones']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Ones']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ones']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ones']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ones']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ones']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ones']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Ones']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ones']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Ones']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Ones']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ones']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ones']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ones']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ones']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ones']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Ones']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ones']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Ones']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Ones']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ones']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ones']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ones']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ones']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ones']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ones']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ones']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ones']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ones']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ones']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Tuples', color='tab:blue', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del tamaño\ndel buffer para el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(min(xfast0Time))
print(min(xfast1Time))
print(min(xfast2Time))
print(min(xfast3Time))
print(min(xfast4Time))
print(min(xfast5Time))
print(min(xfast6Time))
print(min(xfast7Time))
print(min(xfast8Time))

# %% [markdown]
# ## Poisson runs insert + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ones']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ones']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ones']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Ones']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ones']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Ones']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Ones']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ones']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ones']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ones']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ones']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ones']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Ones']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ones']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Ones']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Ones']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ones']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ones']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ones']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ones']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ones']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Ones']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ones']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Ones']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Ones']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ones']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ones']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ones']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ones']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ones']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Ones']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ones']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Ones']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Ones']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ones']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ones']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ones']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ones']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ones']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Ones']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ones']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Ones']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Ones']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ones']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ones']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ones']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ones']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ones']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Ones']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ones']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Ones']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Ones']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ones']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ones']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ones']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ones']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ones']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Ones']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ones']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Ones']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Ones']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ones']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ones']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ones']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ones']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ones']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Ones']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ones']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Ones']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Ones']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ones']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ones']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Insert Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ones']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Insert Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ones']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ones']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Insert Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ones']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Ones']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Insert Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Ones']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ones']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Insert Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ones']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Ones']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Insert Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Ones']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Ones']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Insert Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Ones']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ones']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Insert Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ones']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Ones']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Insert Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ones']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ones']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ones']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ones']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ones']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ones']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ones']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ones']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ones']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Create Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ones']*1000]*3

tuplesLineal0Size.sort()
btree0Size.sort()
redBlack0Size.sort()
yfastUR0Size.sort()
yfast0Size.sort()
xfast0Size.sort()
avl0Size.sort()
tuplesLineal1Size.sort()
btree1Size.sort()
redBlack1Size.sort()
yfastUR1Size.sort()
yfast1Size.sort()
xfast1Size.sort()
avl1Size.sort()
tuplesLineal2Size.sort()
btree2Size.sort()
redBlack2Size.sort()
yfastUR2Size.sort()
yfast2Size.sort()
xfast2Size.sort()
avl2Size.sort()
tuplesLineal3Size.sort()
btree3Size.sort()
redBlack3Size.sort()
yfastUR3Size.sort()
yfast3Size.sort()
xfast3Size.sort()
avl3Size.sort()
tuplesLineal4Size.sort()
btree4Size.sort()
redBlack4Size.sort()
yfastUR4Size.sort()
yfast4Size.sort()
xfast4Size.sort()
avl4Size.sort()
tuplesLineal5Size.sort()
btree5Size.sort()
redBlack5Size.sort()
yfastUR5Size.sort()
yfast5Size.sort()
xfast5Size.sort()
avl5Size.sort()
tuplesLineal6Size.sort()
btree6Size.sort()
redBlack6Size.sort()
yfastUR6Size.sort()
yfast6Size.sort()
xfast6Size.sort()
avl6Size.sort()
tuplesLineal7Size.sort()
btree7Size.sort()
redBlack7Size.sort()
yfastUR7Size.sort()
yfast7Size.sort()
xfast7Size.sort()
avl7Size.sort()
tuplesLineal8Size.sort()
btree8Size.sort()
redBlack8Size.sort()
yfastUR8Size.sort()
yfast8Size.sort()
xfast8Size.sort()
avl8Size.sort()

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].plot(tuplesLineal0Size, tuplesMean0Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesMean1Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesMean2Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].plot(tuplesLineal3Size, tuplesMean3Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesMean4Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesMean5Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].plot(tuplesLineal6Size, tuplesMean6Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesMean7Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesMean8Time, label = 'Tuples', color='tab:blue', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de inserción por cada 1 recibido en función del espacio utilizado\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":13, "weight":"bold"})

plt.show()
print(sdVectorRR0Time)
print(sdVectorRR1Time)
print(sdVectorRR2Time)
print(sdVectorRR3Time)
print(sdVectorRR4Time)
print(sdVectorRR5Time)
print(sdVectorRR6Time)
print(sdVectorRR7Time)
print(sdVectorRR8Time)

# %% [markdown]
# ## Poisson Runs Rank Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ranks']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ranks']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Ranks']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ranks']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Ranks']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Ranks']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ranks']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ranks']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ranks']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Ranks']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ranks']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Ranks']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Ranks']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ranks']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ranks']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ranks']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Ranks']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ranks']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Ranks']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Ranks']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ranks']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ranks']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ranks']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Ranks']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ranks']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Ranks']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Ranks']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ranks']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ranks']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ranks']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Ranks']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ranks']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Ranks']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Ranks']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ranks']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000,
]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorPR0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorPR9Time, label = 'sd vector NC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorPR1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorPR10Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorPR2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorPR11Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorPR3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorPR12Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorPR4Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorPR13Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorPR5Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorPR14Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorPR6Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorPR15Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorPR7Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorPR8Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Poisson runs rank + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ranks']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ranks']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Ranks']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ranks']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Ranks']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Ranks']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ranks']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ranks']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ranks']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Ranks']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ranks']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Ranks']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Ranks']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ranks']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ranks']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ranks']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Ranks']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ranks']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Ranks']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Ranks']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ranks']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ranks']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ranks']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Ranks']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ranks']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Ranks']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Ranks']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ranks']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ranks']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ranks']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Ranks']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ranks']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Ranks']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Ranks']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ranks']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ranks']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ranks']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Ranks']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ranks']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Ranks']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Ranks']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ranks']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ranks']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ranks']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Ranks']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ranks']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Ranks']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Ranks']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ranks']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ranks']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ranks']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Ranks']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ranks']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Ranks']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Ranks']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ranks']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ranks']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ranks']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ranks']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Rank Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ranks']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Ranks']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Random Rank Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Ranks']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ranks']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Rank Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ranks']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Ranks']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Random Rank Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Ranks']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Ranks']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Rank Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Ranks']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ranks']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Rank Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ranks']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Ranks']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000,
]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Poisson Runs Rank Time Last Million

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 54].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 54].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 54].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 145].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 145].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 145].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 236].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 236].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 236].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 54].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 145].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 236].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 54].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 54].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 54].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 145].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 145].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 145].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 236].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 236].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 236].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 54].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 54].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 145].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 145].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 236].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 236].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 54].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 145].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 236].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 54].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 54].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 145].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 145].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 236].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 236].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 67].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 67].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 67].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 158].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 158].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 158].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 249].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 249].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 249].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 67].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 158].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 249].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 67].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 67].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 67].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 158].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 158].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 158].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 249].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 249].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 249].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 67].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 67].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 158].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 158].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 249].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 249].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 67].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 158].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 249].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 67].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 67].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 158].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 158].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 249].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 249].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 80].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 80].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 80].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 171].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 171].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 171].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 262].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 262].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 262].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 80].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 171].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 262].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 80].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 80].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 80].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 171].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 171].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 171].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 262].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 262].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 262].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 80].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 80].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 171].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 171].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 262].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 262].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 80].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 171].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 262].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 80].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 80].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 171].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 171].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 262].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 262].iloc[-2]['Ranks'])*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 60].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 60].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 60].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 151].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 151].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 151].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 242].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 242].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 242].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 60].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 151].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 242].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 60].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 60].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 60].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 151].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 151].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 151].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 242].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 242].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 242].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 60].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 60].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 151].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 151].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 242].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 242].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 60].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 151].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 242].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 60].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 60].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 151].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 151].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 242].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 242].iloc[-2]['Ranks'])*1000,
]

tuplesLineal4Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation4Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
tuplesBinary4Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
btree4Time = [
  (btree.loc[btree['confID'] == 73].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 73].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 73].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 164].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 164].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 164].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 255].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 255].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 255].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
redBlack4Time = [
  (redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 73].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 164].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 255].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
avl4Time = [
  (avl.loc[avl['confID'] == 73].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 73].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 73].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 164].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 164].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 164].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 255].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 255].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 255].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
xfast4Time = [
  (xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 73].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 73].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 164].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 164].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 255].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 255].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
yfastUR4Time = [
  (yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 73].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 164].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 255].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
yfast4Time = [
  (yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 73].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 73].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 164].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 164].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 255].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 255].iloc[-2]['Ranks'])*1000,
]

tuplesLineal5Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation5Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
tuplesBinary5Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
btree5Time = [
  (btree.loc[btree['confID'] == 86].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 86].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 86].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 177].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 177].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 177].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 268].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 268].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 268].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
redBlack5Time = [
  (redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 86].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 177].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 268].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
avl5Time = [
  (avl.loc[avl['confID'] == 86].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 86].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 86].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 177].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 177].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 177].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 268].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 268].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 268].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
xfast5Time = [
  (xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 86].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 86].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 177].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 177].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 268].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 268].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
yfastUR5Time = [
  (yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 86].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 177].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 268].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
yfast5Time = [
  (yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 86].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 86].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 177].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 177].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 268].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 268].iloc[-2]['Ranks'])*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation6Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
tuplesBinary6Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
btree6Time = [
  (btree.loc[btree['confID'] == 53].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 53].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 53].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 144].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 144].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 144].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 235].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 235].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 235].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
redBlack6Time = [
  (redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 53].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 144].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 235].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
avl6Time = [
  (avl.loc[avl['confID'] == 53].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 53].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 53].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 144].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 144].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 144].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 235].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 235].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 235].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
xfast6Time = [
  (xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 53].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 53].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 144].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 144].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 235].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 235].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
yfastUR6Time = [
  (yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 53].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 144].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 235].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
yfast6Time = [
  (yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 53].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 53].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 144].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 144].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 235].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 235].iloc[-2]['Ranks'])*1000,
]

tuplesLineal7Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation7Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
tuplesBinary7Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
btree7Time = [
  (btree.loc[btree['confID'] == 66].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 66].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 66].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 157].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 157].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 157].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 248].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 248].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 248].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
redBlack7Time = [
  (redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 66].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 157].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 248].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
avl7Time = [
  (avl.loc[avl['confID'] == 66].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 66].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 66].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 157].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 157].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 157].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 248].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 248].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 248].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
xfast7Time = [
  (xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 66].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 66].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 157].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 157].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 248].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 248].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
yfastUR7Time = [
  (yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 66].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 157].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 248].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
yfast7Time = [
  (yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 66].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 66].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 157].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 157].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 248].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 248].iloc[-2]['Ranks'])*1000,
]

tuplesLineal8Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation8Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
tuplesBinary8Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
btree8Time = [
  (btree.loc[btree['confID'] == 79].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 79].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 79].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 170].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 170].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 170].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 261].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 261].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 261].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
redBlack8Time = [
  (redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 79].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 170].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 261].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
avl8Time = [
  (avl.loc[avl['confID'] == 79].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 79].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 79].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 170].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 170].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 170].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 261].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 261].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 261].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
xfast8Time = [
  (xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 79].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 79].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 170].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 170].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 261].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 261].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
yfastUR8Time = [
  (yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 79].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 170].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 261].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
yfast8Time = [
  (yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 79].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 79].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 170].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 170].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 261].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 261].iloc[-2]['Ranks'])*1000,
]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2)
ax[0,0].plot(bufferSizes, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2)
ax[0,0].plot(bufferSizes, btree0Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,0].plot(bufferSizes, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,0].plot(bufferSizes, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,0].plot(bufferSizes, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,0].plot(bufferSizes, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,0].plot(bufferSizes, avl0Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorPR0Time, label = 'sd vector', color='tab:pink', linewidth=2)
ax[0,0].plot(bufferSizes, sdVectorPR9Time, label = 'sd vector NC', color='indigo', linewidth=2)
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,1].plot(bufferSizes, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,1].plot(bufferSizes, btree1Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,1].plot(bufferSizes, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,1].plot(bufferSizes, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,1].plot(bufferSizes, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,1].plot(bufferSizes, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,1].plot(bufferSizes, avl1Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorPR1Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,1].plot(bufferSizes, sdVectorPR10Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[0,2].plot(bufferSizes, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[0,2].plot(bufferSizes, btree2Time, label = 'btree', color='tab:orange', linewidth=2)
ax[0,2].plot(bufferSizes, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[0,2].plot(bufferSizes, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[0,2].plot(bufferSizes, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[0,2].plot(bufferSizes, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[0,2].plot(bufferSizes, avl2Time, label = 'avl', color='tab:brown', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorPR2Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[0,2].plot(bufferSizes, sdVectorPR11Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,0].plot(bufferSizes, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,0].plot(bufferSizes, btree3Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,0].plot(bufferSizes, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,0].plot(bufferSizes, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,0].plot(bufferSizes, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,0].plot(bufferSizes, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,0].plot(bufferSizes, avl3Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorPR3Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,0].plot(bufferSizes, sdVectorPR12Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,1].plot(bufferSizes, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,1].plot(bufferSizes, btree4Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,1].plot(bufferSizes, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,1].plot(bufferSizes, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,1].plot(bufferSizes, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,1].plot(bufferSizes, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,1].plot(bufferSizes, avl4Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorPR4Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,1].plot(bufferSizes, sdVectorPR13Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[1,2].plot(bufferSizes, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[1,2].plot(bufferSizes, btree5Time, label = 'btree', color='tab:orange', linewidth=2)
ax[1,2].plot(bufferSizes, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[1,2].plot(bufferSizes, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[1,2].plot(bufferSizes, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[1,2].plot(bufferSizes, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[1,2].plot(bufferSizes, avl5Time, label = 'avl', color='tab:brown', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorPR5Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[1,2].plot(bufferSizes, sdVectorPR14Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,0].plot(bufferSizes, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,0].plot(bufferSizes, btree6Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,0].plot(bufferSizes, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,0].plot(bufferSizes, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,0].plot(bufferSizes, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,0].plot(bufferSizes, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,0].plot(bufferSizes, avl6Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorPR6Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,0].plot(bufferSizes, sdVectorPR15Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,1].plot(bufferSizes, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,1].plot(bufferSizes, btree7Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,1].plot(bufferSizes, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,1].plot(bufferSizes, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,1].plot(bufferSizes, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,1].plot(bufferSizes, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,1].plot(bufferSizes, avl7Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorPR7Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,1].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2)
ax[2,2].plot(bufferSizes, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2)
ax[2,2].plot(bufferSizes, btree8Time, label = 'btree', color='tab:orange', linewidth=2)
ax[2,2].plot(bufferSizes, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2)
ax[2,2].plot(bufferSizes, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2)
ax[2,2].plot(bufferSizes, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2)
ax[2,2].plot(bufferSizes, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2)
ax[2,2].plot(bufferSizes, avl8Time, label = 'avl', color='tab:brown', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorPR8Time, label = 'sd_vector', color='tab:pink', linewidth=2)
ax[2,2].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vector NC', color='indigo', linewidth=2)
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del tamaño del buffer durante\nel último millón de bits para el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Poisson runs rank last million + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation0Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
tuplesBinary0Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
btree0Time = [
  (btree.loc[btree['confID'] == 54].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 54].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 54].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 145].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 145].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 145].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 236].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 236].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 236].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
redBlack0Time = [
  (redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 54].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 145].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 236].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
avl0Time = [
  (avl.loc[avl['confID'] == 54].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 54].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 54].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 145].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 145].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 145].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 236].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 236].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 236].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
xfast0Time = [
  (xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 54].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 54].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 145].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 145].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 236].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 236].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
yfastUR0Time = [
  (yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 54].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 145].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 236].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 236].iloc[-2]['Ranks'])*1000,
]
yfast0Time = [
  (yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 54].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 54].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 54].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 145].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 145].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 145].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 236].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 236].iloc[-2]['Ranks'])*1000,
]

tuplesLineal1Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation1Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
tuplesBinary1Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
btree1Time = [
  (btree.loc[btree['confID'] == 67].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 67].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 67].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 158].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 158].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 158].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 249].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 249].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 249].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
redBlack1Time = [
  (redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 67].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 158].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 249].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
avl1Time = [
  (avl.loc[avl['confID'] == 67].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 67].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 67].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 158].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 158].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 158].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 249].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 249].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 249].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
xfast1Time = [
  (xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 67].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 67].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 158].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 158].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 249].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 249].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
yfastUR1Time = [
  (yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 67].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 158].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 249].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 249].iloc[-2]['Ranks'])*1000,
]
yfast1Time = [
  (yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 67].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 67].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 67].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 158].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 158].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 158].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 249].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 249].iloc[-2]['Ranks'])*1000,
]

tuplesLineal2Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation2Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
tuplesBinary2Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
btree2Time = [
  (btree.loc[btree['confID'] == 80].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 80].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 80].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 171].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 171].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 171].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 262].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 262].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 262].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
redBlack2Time = [
  (redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 80].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 171].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 262].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
avl2Time = [
  (avl.loc[avl['confID'] == 80].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 80].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 80].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 171].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 171].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 171].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 262].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 262].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 262].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
xfast2Time = [
  (xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 80].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 80].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 171].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 171].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 262].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 262].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
yfastUR2Time = [
  (yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 80].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 171].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 262].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 262].iloc[-2]['Ranks'])*1000,
]
yfast2Time = [
  (yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 80].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 80].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 80].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 171].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 171].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 171].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 262].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 262].iloc[-2]['Ranks'])*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation3Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
tuplesBinary3Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
btree3Time = [
  (btree.loc[btree['confID'] == 60].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 60].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 60].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 151].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 151].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 151].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 242].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 242].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 242].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
redBlack3Time = [
  (redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 60].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 151].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 242].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
avl3Time = [
  (avl.loc[avl['confID'] == 60].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 60].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 60].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 151].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 151].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 151].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 242].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 242].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 242].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
xfast3Time = [
  (xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 60].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 60].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 151].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 151].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 242].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 242].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
yfastUR3Time = [
  (yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 60].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 151].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 242].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 242].iloc[-2]['Ranks'])*1000,
]
yfast3Time = [
  (yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 60].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 60].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 60].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 151].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 151].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 151].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 242].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 242].iloc[-2]['Ranks'])*1000,
]

tuplesLineal4Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation4Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
tuplesBinary4Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
btree4Time = [
  (btree.loc[btree['confID'] == 73].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 73].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 73].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 164].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 164].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 164].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 255].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 255].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 255].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
redBlack4Time = [
  (redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 73].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 164].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 255].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
avl4Time = [
  (avl.loc[avl['confID'] == 73].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 73].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 73].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 164].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 164].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 164].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 255].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 255].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 255].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
xfast4Time = [
  (xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 73].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 73].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 164].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 164].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 255].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 255].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
yfastUR4Time = [
  (yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 73].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 164].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 255].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 255].iloc[-2]['Ranks'])*1000,
]
yfast4Time = [
  (yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 73].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 73].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 73].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 164].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 164].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 164].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 255].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 255].iloc[-2]['Ranks'])*1000,
]

tuplesLineal5Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation5Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
tuplesBinary5Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
btree5Time = [
  (btree.loc[btree['confID'] == 86].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 86].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 86].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 177].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 177].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 177].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 268].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 268].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 268].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
redBlack5Time = [
  (redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 86].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 177].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 268].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
avl5Time = [
  (avl.loc[avl['confID'] == 86].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 86].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 86].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 177].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 177].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 177].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 268].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 268].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 268].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
xfast5Time = [
  (xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 86].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 86].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 177].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 177].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 268].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 268].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
yfastUR5Time = [
  (yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 86].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 177].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 268].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 268].iloc[-2]['Ranks'])*1000,
]
yfast5Time = [
  (yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 86].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 86].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 86].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 177].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 177].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 177].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 268].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 268].iloc[-2]['Ranks'])*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation6Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
tuplesBinary6Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
btree6Time = [
  (btree.loc[btree['confID'] == 53].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 53].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 53].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 144].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 144].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 144].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 235].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 235].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 235].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
redBlack6Time = [
  (redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 53].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 144].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 235].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
avl6Time = [
  (avl.loc[avl['confID'] == 53].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 53].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 53].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 144].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 144].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 144].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 235].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 235].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 235].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
xfast6Time = [
  (xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 53].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 53].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 144].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 144].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 235].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 235].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
yfastUR6Time = [
  (yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 53].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 144].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 235].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 235].iloc[-2]['Ranks'])*1000,
]
yfast6Time = [
  (yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 53].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 53].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 53].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 144].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 144].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 144].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 235].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 235].iloc[-2]['Ranks'])*1000,
]

tuplesLineal7Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation7Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
tuplesBinary7Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
btree7Time = [
  (btree.loc[btree['confID'] == 66].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 66].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 66].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 157].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 157].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 157].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 248].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 248].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 248].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
redBlack7Time = [
  (redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 66].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 157].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 248].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
avl7Time = [
  (avl.loc[avl['confID'] == 66].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 66].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 66].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 157].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 157].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 157].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 248].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 248].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 248].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
xfast7Time = [
  (xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 66].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 66].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 157].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 157].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 248].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 248].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
yfastUR7Time = [
  (yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 66].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 157].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 248].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 248].iloc[-2]['Ranks'])*1000,
]
yfast7Time = [
  (yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 66].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 66].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 66].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 157].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 157].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 157].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 248].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 248].iloc[-2]['Ranks'])*1000,
]

tuplesLineal8Time = [
  (tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Ranks']-tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
tuplesInterpolation8Time = [
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Ranks']-tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
tuplesBinary8Time = [
  (tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Rank Time']-tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-2]['Random Rank Time'])/(tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Ranks']-tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
btree8Time = [
  (btree.loc[btree['confID'] == 79].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 79].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 79].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 170].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 170].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 170].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (btree.loc[btree['confID'] == 261].iloc[-1]['Random Rank Time']-btree.loc[btree['confID'] == 261].iloc[-2]['Random Rank Time'])/(btree.loc[btree['confID'] == 261].iloc[-1]['Ranks']-btree.loc[btree['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
redBlack8Time = [
  (redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 79].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 170].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Rank Time']-redBlack.loc[redBlack['confID'] == 261].iloc[-2]['Random Rank Time'])/(redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Ranks']-redBlack.loc[redBlack['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
avl8Time = [
  (avl.loc[avl['confID'] == 79].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 79].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 79].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 170].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 170].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 170].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (avl.loc[avl['confID'] == 261].iloc[-1]['Random Rank Time']-avl.loc[avl['confID'] == 261].iloc[-2]['Random Rank Time'])/(avl.loc[avl['confID'] == 261].iloc[-1]['Ranks']-avl.loc[avl['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
xfast8Time = [
  (xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 79].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 79].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 170].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 170].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Rank Time']-xfast.loc[xfast['confID'] == 261].iloc[-2]['Random Rank Time'])/(xfast.loc[xfast['confID'] == 261].iloc[-1]['Ranks']-xfast.loc[xfast['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
yfastUR8Time = [
  (yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 79].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 170].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Rank Time']-yfastUR.loc[yfastUR['confID'] == 261].iloc[-2]['Random Rank Time'])/(yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Ranks']-yfastUR.loc[yfastUR['confID'] == 261].iloc[-2]['Ranks'])*1000,
]
yfast8Time = [
  (yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 79].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 79].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 79].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 170].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 170].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 170].iloc[-2]['Ranks'])*1000,
  (yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Rank Time']-yfast.loc[yfast['confID'] == 261].iloc[-2]['Random Rank Time'])/(yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']-yfast.loc[yfast['confID'] == 261].iloc[-2]['Ranks'])*1000,
]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Ranks']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Ranks']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Ranks']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Ranks']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Ranks']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Ranks']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Ranks']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Ranks']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Rank Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Ranks']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación rank en función del espacio utilizado durante\nel último millón de bits para el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":11, "weight":"bold"})

plt.show()

# %% [markdown]
# ## Poisson Runs Select Time

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Selects']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Selects']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Selects']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Selects']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Selects']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Selects']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Selects']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Selects']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Selects']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Selects']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Selects']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Selects']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Selects']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Selects']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Selects']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Selects']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Selects']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Selects']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Selects']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Selects']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Selects']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Selects']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Selects']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Selects']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Selects']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Selects']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Selects']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Selects']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Selects']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Selects']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Selects']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Selects']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Selects']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Selects']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Selects']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Selects']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Selects']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Selects']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Selects']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Selects']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]
mean4Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree4Time, redBlack4Time, avl4Time, xfast4Time, yfastUR4Time, yfast4Time)]
mean5Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree5Time, redBlack5Time, avl5Time, xfast5Time, yfastUR5Time, yfast5Time)]
mean6Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree6Time, redBlack6Time, avl6Time, xfast6Time, yfastUR6Time, yfast6Time)]
mean7Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree7Time, redBlack7Time, avl7Time, xfast7Time, yfastUR7Time, yfast7Time)]
mean8Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree8Time, redBlack8Time, avl8Time, xfast8Time, yfastUR8Time, yfast8Time)]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(bufferSizes, tuplesMean0Time, label = 'Tuples', color='tab:blue')
ax[0,0].plot(bufferSizes, mean0Time, label = 'Extensible\nElias Fano', color='darkorange')
ax[0,0].plot(bufferSizes, sdVectorPR0Time, label = 'sd vector', color='tab:pink')
ax[0,0].plot(bufferSizes, sdVectorPR9Time, label = 'sd vectorNC', color='indigo')
ax[0,0].set_xticks(bufferSizes)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(bufferSizes, tuplesMean1Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[0,1].plot(bufferSizes, mean1Time, label = 'Extensible Elias Fano', color='darkorange')
ax[0,1].plot(bufferSizes, sdVectorPR1Time, label = 'sd_vector', color='tab:pink')
ax[0,1].plot(bufferSizes, sdVectorPR10Time, label = 'sd_vectorNC', color='indigo')
ax[0,1].set_xticks(bufferSizes)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(bufferSizes, tuplesMean2Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[0,2].plot(bufferSizes, mean2Time, label = 'Extensible Elias Fano', color='darkorange')
ax[0,2].plot(bufferSizes, sdVectorPR2Time, label = 'sd_vector', color='tab:pink')
ax[0,2].plot(bufferSizes, sdVectorPR11Time, label = 'sd_vectorNC', color='indigo')
ax[0,2].set_xticks(bufferSizes)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(bufferSizes, tuplesMean3Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,0].plot(bufferSizes, mean3Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,0].plot(bufferSizes, sdVectorPR3Time, label = 'sd_vector', color='tab:pink')
ax[1,0].plot(bufferSizes, sdVectorPR12Time, label = 'sd_vectorNC', color='indigo')
ax[1,0].set_xticks(bufferSizes)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(bufferSizes, tuplesMean4Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,1].plot(bufferSizes, mean4Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,1].plot(bufferSizes, sdVectorPR4Time, label = 'sd_vector', color='tab:pink')
ax[1,1].plot(bufferSizes, sdVectorPR13Time, label = 'sd_vectorNC', color='indigo')
ax[1,1].set_xticks(bufferSizes)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(bufferSizes, tuplesMean5Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[1,2].plot(bufferSizes, mean5Time, label = 'Extensible Elias Fano', color='darkorange')
ax[1,2].plot(bufferSizes, sdVectorPR5Time, label = 'sd_vector', color='tab:pink')
ax[1,2].plot(bufferSizes, sdVectorPR14Time, label = 'sd_vectorNC', color='indigo')
ax[1,2].set_xticks(bufferSizes)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(bufferSizes, tuplesMean6Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,0].plot(bufferSizes, mean6Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,0].plot(bufferSizes, sdVectorPR6Time, label = 'sd_vector', color='tab:pink')
ax[2,0].plot(bufferSizes, sdVectorPR15Time, label = 'sd_vectorNC', color='indigo')
ax[2,0].set_xticks(bufferSizes)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(bufferSizes, tuplesMean7Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,1].plot(bufferSizes, mean7Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,1].plot(bufferSizes, sdVectorPR7Time, label = 'sd_vector', color='tab:pink')
ax[2,1].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vectorNC', color='indigo')
ax[2,1].set_xticks(bufferSizes)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(bufferSizes, tuplesMean8Time, label = 'Extensible Elias Fano Tuples', color='tab:blue')
ax[2,2].plot(bufferSizes, mean8Time, label = 'Extensible Elias Fano', color='darkorange')
ax[2,2].plot(bufferSizes, sdVectorPR8Time, label = 'sd_vector', color='tab:pink')
ax[2,2].plot(bufferSizes, sdVectorPR16Time, label = 'sd_vectorNC', color='indigo')
ax[2,2].set_xticks(bufferSizes)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Tamaño del buffer', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del tamaño del buffer\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":12, 'weight':'bold'})

plt.show()

# %% [markdown]
# ## Poisson runs select + space

# %%
density0 = round(tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Ones']/100000000, 2)
density1 = round(tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Ones']/100000000, 2)
density2 = round(tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Ones']/100000000, 2)

tuplesLineal0Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 236].iloc[-1]['Selects']*1000,
]
tuplesInterpolation0Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 236].iloc[-1]['Selects']*1000,
]
tuplesBinary0Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 54].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 145].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 236].iloc[-1]['Selects']*1000,
]
btree0Time = [
  btree.loc[btree['confID'] == 54].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 54].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 145].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 145].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 236].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 236].iloc[-1]['Selects']*1000,
]
redBlack0Time = [
  redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 54].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 145].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 236].iloc[-1]['Selects']*1000,
]
avl0Time = [
  avl.loc[avl['confID'] == 54].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 54].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 145].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 145].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 236].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 236].iloc[-1]['Selects']*1000,
]
xfast0Time = [
  xfast.loc[xfast['confID'] == 54].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 54].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 145].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 145].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 236].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 236].iloc[-1]['Selects']*1000,
]
yfastUR0Time = [
  yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 54].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 145].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 236].iloc[-1]['Selects']*1000,
]
yfast0Time = [
  yfast.loc[yfast['confID'] == 54].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 54].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 145].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 145].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 236].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000,
]

tuplesLineal1Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 249].iloc[-1]['Selects']*1000,
]
tuplesInterpolation1Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 249].iloc[-1]['Selects']*1000,
]
tuplesBinary1Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 67].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 158].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 249].iloc[-1]['Selects']*1000,
]
btree1Time = [
  btree.loc[btree['confID'] == 67].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 67].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 158].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 158].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 249].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 249].iloc[-1]['Selects']*1000,
]
redBlack1Time = [
  redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 67].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 158].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 249].iloc[-1]['Selects']*1000,
]
avl1Time = [
  avl.loc[avl['confID'] == 67].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 67].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 158].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 158].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 249].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 249].iloc[-1]['Selects']*1000,
]
xfast1Time = [
  xfast.loc[xfast['confID'] == 67].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 67].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 158].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 158].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 249].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 249].iloc[-1]['Selects']*1000,
]
yfastUR1Time = [
  yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 67].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 158].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 249].iloc[-1]['Selects']*1000,
]
yfast1Time = [
  yfast.loc[yfast['confID'] == 67].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 67].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 158].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 158].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 249].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000,
]

tuplesLineal2Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 262].iloc[-1]['Selects']*1000,
]
tuplesInterpolation2Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 262].iloc[-1]['Selects']*1000,
]
tuplesBinary2Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 80].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 171].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 262].iloc[-1]['Selects']*1000,
]
btree2Time = [
  btree.loc[btree['confID'] == 80].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 80].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 171].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 171].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 262].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 262].iloc[-1]['Selects']*1000,
]
redBlack2Time = [
  redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 80].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 171].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 262].iloc[-1]['Selects']*1000,
]
avl2Time = [
  avl.loc[avl['confID'] == 80].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 80].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 171].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 171].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 262].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 262].iloc[-1]['Selects']*1000,
]
xfast2Time = [
  xfast.loc[xfast['confID'] == 80].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 80].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 171].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 171].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 262].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 262].iloc[-1]['Selects']*1000,
]
yfastUR2Time = [
  yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 80].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 171].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 262].iloc[-1]['Selects']*1000,
]
yfast2Time = [
  yfast.loc[yfast['confID'] == 80].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 80].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 171].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 171].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 262].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000,
]

density3 = round(tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Ones']/100000000, 2)
density4 = round(tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Ones']/100000000, 2)
density5 = round(tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Ones']/100000000, 2)

tuplesLineal3Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 242].iloc[-1]['Selects']*1000,
]
tuplesInterpolation3Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 242].iloc[-1]['Selects']*1000,
]
tuplesBinary3Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 60].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 151].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 242].iloc[-1]['Selects']*1000,
]
btree3Time = [
  btree.loc[btree['confID'] == 60].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 60].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 151].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 151].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 242].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 242].iloc[-1]['Selects']*1000,
]
redBlack3Time = [
  redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 60].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 151].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 242].iloc[-1]['Selects']*1000,
]
avl3Time = [
  avl.loc[avl['confID'] == 60].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 60].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 151].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 151].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 242].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 242].iloc[-1]['Selects']*1000,
]
xfast3Time = [
  xfast.loc[xfast['confID'] == 60].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 60].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 151].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 151].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 242].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 242].iloc[-1]['Selects']*1000,
]
yfastUR3Time = [
  yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 60].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 151].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 242].iloc[-1]['Selects']*1000,
]
yfast3Time = [
  yfast.loc[yfast['confID'] == 60].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 60].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 151].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 151].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 242].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000,
]

tuplesLineal4Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 255].iloc[-1]['Selects']*1000,
]
tuplesInterpolation4Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 255].iloc[-1]['Selects']*1000,
]
tuplesBinary4Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 73].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 164].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 255].iloc[-1]['Selects']*1000,
]
btree4Time = [
  btree.loc[btree['confID'] == 73].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 73].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 164].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 164].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 255].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 255].iloc[-1]['Selects']*1000,
]
redBlack4Time = [
  redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 73].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 164].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 255].iloc[-1]['Selects']*1000,
]
avl4Time = [
  avl.loc[avl['confID'] == 73].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 73].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 164].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 164].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 255].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 255].iloc[-1]['Selects']*1000,
]
xfast4Time = [
  xfast.loc[xfast['confID'] == 73].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 73].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 164].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 164].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 255].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 255].iloc[-1]['Selects']*1000,
]
yfastUR4Time = [
  yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 73].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 164].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 255].iloc[-1]['Selects']*1000,
]
yfast4Time = [
  yfast.loc[yfast['confID'] == 73].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 73].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 164].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 164].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 255].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000,
]

tuplesLineal5Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 268].iloc[-1]['Selects']*1000,
]
tuplesInterpolation5Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 268].iloc[-1]['Selects']*1000,
]
tuplesBinary5Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 86].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 177].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 268].iloc[-1]['Selects']*1000,
]
btree5Time = [
  btree.loc[btree['confID'] == 86].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 86].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 177].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 177].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 268].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 268].iloc[-1]['Selects']*1000,
]
redBlack5Time = [
  redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 86].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 177].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 268].iloc[-1]['Selects']*1000,
]
avl5Time = [
  avl.loc[avl['confID'] == 86].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 86].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 177].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 177].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 268].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 268].iloc[-1]['Selects']*1000,
]
xfast5Time = [
  xfast.loc[xfast['confID'] == 86].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 86].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 177].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 177].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 268].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 268].iloc[-1]['Selects']*1000,
]
yfastUR5Time = [
  yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 86].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 177].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 268].iloc[-1]['Selects']*1000,
]
yfast5Time = [
  yfast.loc[yfast['confID'] == 86].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 86].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 177].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 177].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 268].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000,
]

density6 = round(tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Ones']/100000000, 2)
density7 = round(tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Ones']/100000000, 2)
density8 = round(tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Ones']/100000000, 2)

tuplesLineal6Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 235].iloc[-1]['Selects']*1000,
]
tuplesInterpolation6Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 235].iloc[-1]['Selects']*1000,
]
tuplesBinary6Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 53].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 144].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 235].iloc[-1]['Selects']*1000,
]
btree6Time = [
  btree.loc[btree['confID'] == 53].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 53].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 144].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 144].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 235].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 235].iloc[-1]['Selects']*1000,
]
redBlack6Time = [
  redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 53].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 144].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 235].iloc[-1]['Selects']*1000,
]
avl6Time = [
  avl.loc[avl['confID'] == 53].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 53].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 144].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 144].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 235].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 235].iloc[-1]['Selects']*1000,
]
xfast6Time = [
  xfast.loc[xfast['confID'] == 53].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 53].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 144].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 144].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 235].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 235].iloc[-1]['Selects']*1000,
]
yfastUR6Time = [
  yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 53].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 144].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 235].iloc[-1]['Selects']*1000,
]
yfast6Time = [
  yfast.loc[yfast['confID'] == 53].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 53].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 144].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 144].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 235].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000,
]

tuplesLineal7Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 248].iloc[-1]['Selects']*1000,
]
tuplesInterpolation7Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 248].iloc[-1]['Selects']*1000,
]
tuplesBinary7Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 66].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 157].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 248].iloc[-1]['Selects']*1000,
]
btree7Time = [
  btree.loc[btree['confID'] == 66].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 66].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 157].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 157].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 248].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 248].iloc[-1]['Selects']*1000,
]
redBlack7Time = [
  redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 66].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 157].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 248].iloc[-1]['Selects']*1000,
]
avl7Time = [
  avl.loc[avl['confID'] == 66].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 66].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 157].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 157].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 248].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 248].iloc[-1]['Selects']*1000,
]
xfast7Time = [
  xfast.loc[xfast['confID'] == 66].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 66].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 157].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 157].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 248].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 248].iloc[-1]['Selects']*1000,
]
yfastUR7Time = [
  yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 66].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 157].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 248].iloc[-1]['Selects']*1000,
]
yfast7Time = [
  yfast.loc[yfast['confID'] == 66].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 66].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 157].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 157].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 248].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000,
]

tuplesLineal8Time = [
  tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Random Select Time']/tuplesLineal.loc[tuplesLineal['confID'] == 261].iloc[-1]['Selects']*1000,
]
tuplesInterpolation8Time = [
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Random Select Time']/tuplesInterpolation.loc[tuplesInterpolation['confID'] == 261].iloc[-1]['Selects']*1000,
]
tuplesBinary8Time = [
  tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 79].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 170].iloc[-1]['Selects']*1000,
  tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Random Select Time']/tuplesBinary.loc[tuplesBinary['confID'] == 261].iloc[-1]['Selects']*1000,
]
btree8Time = [
  btree.loc[btree['confID'] == 79].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 79].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 170].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 170].iloc[-1]['Selects']*1000,
  btree.loc[btree['confID'] == 261].iloc[-1]['Random Select Time']/btree.loc[btree['confID'] == 261].iloc[-1]['Selects']*1000,
]
redBlack8Time = [
  redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 79].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 170].iloc[-1]['Selects']*1000,
  redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Random Select Time']/redBlack.loc[redBlack['confID'] == 261].iloc[-1]['Selects']*1000,
]
avl8Time = [
  avl.loc[avl['confID'] == 79].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 79].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 170].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 170].iloc[-1]['Selects']*1000,
  avl.loc[avl['confID'] == 261].iloc[-1]['Random Select Time']/avl.loc[avl['confID'] == 261].iloc[-1]['Selects']*1000,
]
xfast8Time = [
  xfast.loc[xfast['confID'] == 79].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 79].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 170].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 170].iloc[-1]['Selects']*1000,
  xfast.loc[xfast['confID'] == 261].iloc[-1]['Random Select Time']/xfast.loc[xfast['confID'] == 261].iloc[-1]['Selects']*1000,
]
yfastUR8Time = [
  yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 79].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 170].iloc[-1]['Selects']*1000,
  yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Random Select Time']/yfastUR.loc[yfastUR['confID'] == 261].iloc[-1]['Selects']*1000,
]
yfast8Time = [
  yfast.loc[yfast['confID'] == 79].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 79].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 170].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 170].iloc[-1]['Selects']*1000,
  yfast.loc[yfast['confID'] == 261].iloc[-1]['Random Select Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000,
]

tuplesMean0Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal0Time, tuplesBinary0Time, tuplesInterpolation0Time)]
tuplesMean1Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal1Time, tuplesBinary1Time, tuplesInterpolation1Time)]
tuplesMean2Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal2Time, tuplesBinary2Time, tuplesInterpolation2Time)]
tuplesMean3Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal3Time, tuplesBinary3Time, tuplesInterpolation3Time)]
tuplesMean4Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal4Time, tuplesBinary4Time, tuplesInterpolation4Time)]
tuplesMean5Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal5Time, tuplesBinary5Time, tuplesInterpolation5Time)]
tuplesMean6Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal6Time, tuplesBinary6Time, tuplesInterpolation6Time)]
tuplesMean7Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal7Time, tuplesBinary7Time, tuplesInterpolation7Time)]
tuplesMean8Time = [(x + y + z)/3 for x,y,z in zip(tuplesLineal8Time, tuplesBinary8Time, tuplesInterpolation8Time)]

mean0Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree0Time, redBlack0Time, avl0Time, xfast0Time, yfastUR0Time, yfast0Time)]
mean1Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree1Time, redBlack1Time, avl1Time, xfast1Time, yfastUR1Time, yfast1Time)]
mean2Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree2Time, redBlack2Time, avl2Time, xfast2Time, yfastUR2Time, yfast2Time)]
mean3Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree3Time, redBlack3Time, avl3Time, xfast3Time, yfastUR3Time, yfast3Time)]
mean4Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree4Time, redBlack4Time, avl4Time, xfast4Time, yfastUR4Time, yfast4Time)]
mean5Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree5Time, redBlack5Time, avl5Time, xfast5Time, yfastUR5Time, yfast5Time)]
mean6Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree6Time, redBlack6Time, avl6Time, xfast6Time, yfastUR6Time, yfast6Time)]
mean7Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree7Time, redBlack7Time, avl7Time, xfast7Time, yfastUR7Time, yfast7Time)]
mean8Time = [(_1 + _2 + _3 + _4 + _5 + _6)/6 for _1,_2,_3,_4,_5,_6 in zip(btree8Time, redBlack8Time, avl8Time, xfast8Time, yfastUR8Time, yfast8Time)]

sdVectorPR0Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000]*3
sdVectorPR1Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000]*3
sdVectorPR2Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000]*3
sdVectorPR3Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000]*3
sdVectorPR4Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000]*3
sdVectorPR5Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000]*3
sdVectorPR6Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000]*3
sdVectorPR7Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000]*3
sdVectorPR8Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000]*3
sdVectorPR9Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 236].iloc[-1]['Selects']*1000]*3
sdVectorPR10Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 249].iloc[-1]['Selects']*1000]*3
sdVectorPR11Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.01) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 262].iloc[-1]['Selects']*1000]*3
sdVectorPR12Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 242].iloc[-1]['Selects']*1000]*3
sdVectorPR13Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 255].iloc[-1]['Selects']*1000]*3
sdVectorPR14Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.05) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 268].iloc[-1]['Selects']*1000]*3
sdVectorPR15Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 2048)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 235].iloc[-1]['Selects']*1000]*3
sdVectorPR16Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 4096)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 248].iloc[-1]['Selects']*1000]*3
sdVectorPR17Time = [sd_vectorPR.loc[(sd_vectorPR['Density'] == 0.1) & (sd_vectorPR['Run'] == 8192)].iloc[-1]['Select Time NC']/yfast.loc[yfast['confID'] == 261].iloc[-1]['Selects']*1000]*3

fig = plt.figure(figsize=(18, 15))
gs = fig.add_gridspec(3, 3)
ax = gs.subplots()
ax[0,0].sharey(ax[0,1])
ax[0,1].sharey(ax[0,2])
ax[0,0].plot(tuplesLineal0Size, tuplesLineal0Time, label = 'Tuples\nLineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesInterpolation0Time, label = 'Tuples\nInterpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,0].plot(tuplesLineal0Size, tuplesBinary0Time, label = 'Tuples\nBinary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,0].plot(btree0Size, btree0Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,0].plot(redBlack0Size, redBlack0Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,0].plot(yfastUR0Size, yfastUR0Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,0].plot(yfast0Size, yfast0Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,0].plot(xfast0Size, xfast0Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,0].plot(avl0Size, avl0Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR0Time, label = 'sd vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,0].plot(sdVectorRR0Size, sdVectorRR9Time, label = 'sd vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,0].get_xticklabels(), fontweight="bold")
ax[0,0].set_title('Max run 2048, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,1].plot(tuplesLineal1Size, tuplesLineal1Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesInterpolation1Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,1].plot(tuplesLineal1Size, tuplesBinary1Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,1].plot(btree1Size, btree1Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,1].plot(redBlack1Size, redBlack1Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,1].plot(yfastUR1Size, yfastUR1Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,1].plot(yfast1Size, yfast1Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,1].plot(xfast1Size, xfast1Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,1].plot(avl1Size, avl1Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR1Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,1].plot(sdVectorRR1Size, sdVectorRR10Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,1].get_xticklabels(), fontweight="bold")
ax[0,1].set_title('Max run 4096, prob. 0.01', fontsize=15, fontweight='bold')
ax[0,2].plot(tuplesLineal2Size, tuplesLineal2Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesInterpolation2Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[0,2].plot(tuplesLineal2Size, tuplesBinary2Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[0,2].plot(btree2Size, btree2Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[0,2].plot(redBlack2Size, redBlack2Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[0,2].plot(yfastUR2Size, yfastUR2Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[0,2].plot(yfast2Size, yfast2Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[0,2].plot(xfast2Size, xfast2Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[0,2].plot(avl2Size, avl2Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR2Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[0,2].plot(sdVectorRR2Size, sdVectorRR11Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[0,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[0,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[0,2].get_xticklabels(), fontweight="bold")
ax[0,2].set_title('Max run 8192, prob. 0.01', fontsize=15, fontweight='bold')
ax[1,0].sharey(ax[1,1])
ax[1,1].sharey(ax[1,2])
ax[1,0].plot(tuplesLineal3Size, tuplesLineal3Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesInterpolation3Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,0].plot(tuplesLineal3Size, tuplesBinary3Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,0].plot(btree3Size, btree3Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,0].plot(redBlack3Size, redBlack3Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,0].plot(yfastUR3Size, yfastUR3Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,0].plot(yfast3Size, yfast3Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,0].plot(xfast3Size, xfast3Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,0].plot(avl3Size, avl3Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR3Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,0].plot(sdVectorRR3Size, sdVectorRR12Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,0].get_xticklabels(), fontweight="bold")
ax[1,0].set_title('Max run 2048, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,1].plot(tuplesLineal4Size, tuplesLineal4Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesInterpolation4Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,1].plot(tuplesLineal4Size, tuplesBinary4Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,1].plot(btree4Size, btree4Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,1].plot(redBlack4Size, redBlack4Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,1].plot(yfastUR4Size, yfastUR4Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,1].plot(yfast4Size, yfast4Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,1].plot(xfast4Size, xfast4Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,1].plot(avl4Size, avl4Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR4Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,1].plot(sdVectorRR4Size, sdVectorRR13Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,1].get_xticklabels(), fontweight="bold")
ax[1,1].set_title('Max run 4096, prob. 0.05', fontsize=15, fontweight='bold')
ax[1,2].plot(tuplesLineal5Size, tuplesLineal5Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesInterpolation5Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[1,2].plot(tuplesLineal5Size, tuplesBinary5Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[1,2].plot(btree5Size, btree5Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[1,2].plot(redBlack5Size, redBlack5Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[1,2].plot(yfastUR5Size, yfastUR5Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[1,2].plot(yfast5Size, yfast5Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[1,2].plot(xfast5Size, xfast5Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[1,2].plot(avl5Size, avl5Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR5Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[1,2].plot(sdVectorRR5Size, sdVectorRR14Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[1,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[1,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[1,2].get_xticklabels(), fontweight="bold")
ax[1,2].set_title('Max run 8192, prob. 0.05', fontsize=15, fontweight='bold')
ax[2,0].sharey(ax[2,1])
ax[2,1].sharey(ax[2,2])
ax[2,0].plot(tuplesLineal6Size, tuplesLineal6Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesInterpolation6Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,0].plot(tuplesLineal6Size, tuplesBinary6Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,0].plot(btree6Size, btree6Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,0].plot(redBlack6Size, redBlack6Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,0].plot(yfastUR6Size, yfastUR6Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,0].plot(yfast6Size, yfast6Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,0].plot(xfast6Size, xfast6Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,0].plot(avl6Size, avl6Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR6Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,0].plot(sdVectorRR6Size, sdVectorRR15Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,0].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,0].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,0].get_xticklabels(), fontweight="bold")
ax[2,0].set_title('Max run 2048, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,1].plot(tuplesLineal7Size, tuplesLineal7Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesInterpolation7Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,1].plot(tuplesLineal7Size, tuplesBinary7Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,1].plot(btree7Size, btree7Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,1].plot(redBlack7Size, redBlack7Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,1].plot(yfastUR7Size, yfastUR7Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,1].plot(yfast7Size, yfast7Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,1].plot(xfast7Size, xfast7Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,1].plot(avl7Size, avl7Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR7Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,1].plot(sdVectorRR7Size, sdVectorRR16Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,1].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,1].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,1].get_xticklabels(), fontweight="bold")
ax[2,1].set_title('Max run 4096, prob. 0.1', fontsize=15, fontweight='bold')
ax[2,2].plot(tuplesLineal8Size, tuplesLineal8Time, label = 'Tuples Lineal', color='blue', linewidth=2, marker='.', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesInterpolation8Time, label = 'Tuples Interpolation', color='cyan', linewidth=2, marker='p', ms=10)
ax[2,2].plot(tuplesLineal8Size, tuplesBinary8Time, label = 'Tuples Binary', color='teal', linewidth=2, marker='o', ms=10)
ax[2,2].plot(btree8Size, btree8Time, label = 'btree', color='tab:orange', linewidth=2, marker='x', ms=10)
ax[2,2].plot(redBlack8Size, redBlack8Time, label = 'redBlack', color='tab:red', linewidth=2, marker='|', ms=10)
ax[2,2].plot(yfastUR8Size, yfastUR8Time, label = 'yfastUR', color='tab:green', linewidth=2, marker='v', ms=10)
ax[2,2].plot(yfast8Size, yfast8Time, label = 'yfast', color='tab:olive', linewidth=2, marker='^', ms=10)
ax[2,2].plot(xfast8Size, xfast8Time, label = 'xfast', color='tab:purple', linewidth=2, marker='s', ms=10)
ax[2,2].plot(avl8Size, avl8Time, label = 'avl', color='tab:brown', linewidth=2, marker='*', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR8Time, label = 'sd_vector', color='tab:pink', linewidth=2, marker='d', ms=10)
ax[2,2].plot(sdVectorRR8Size, sdVectorRR17Time, label = 'sd_vector NC', color='indigo', linewidth=2, marker='D', ms=10)
ax[2,2].tick_params(axis='both', labelsize=13)
plt.setp(ax[2,2].get_yticklabels(), fontweight="bold")
plt.setp(ax[2,2].get_xticklabels(), fontweight="bold")
ax[2,2].set_title('Max run 8192, prob. 0.1', fontsize=15, fontweight='bold')

fig.supylabel('Tiempo [µs]', fontsize=22, fontweight='bold')
fig.supxlabel('Bits utilizados por bit recibido', fontsize=22, fontweight='bold')
fig.suptitle('Tiempo promedio de la operación select en función del espacio utilizado\npara el caso de secuencias con distribución poisson', fontsize=22, fontweight='bold')
handles, labels = ax[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right', prop={"size":12, 'weight':'bold'})

plt.show()
